# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import pylab
import scipy.stats as ss
import csv
import numpy as np
import sklearn
import glob
from io import StringIO
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from collections import Counter
# Out:
# C:\Users\ywen2\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# Para que sea más sencillo nombrar las variables, vamos a definir dos modelos, añadiremos rev2 para diferenciarlos de los modelos de la revisión 1:
# - **Modelo 1 rev2**: eliminamos las variables Blood Glucose y Glycated-HB
# - **Modelo 2 rev2**: eliminamos también Vitamin-D, HOMA, Insulin

# %% [markdown]
# # 1. PREPROCESADO:

# %% [markdown]
# - **Cargamos las matrices anteriormente creadas** y que fueron divididas en train y test. Cargamos tanto los pacientes con sus variables y revisiones como las etiquetas asociadas a cada paciente

# %%
X_train = np.load('Conjunto_train.npy')
X_test = np.load('Conjunto_test.npy')
y_train = np.load('Labels_train.npy')
y_test = np.load('Labels_test.npy')

# %% [markdown]
# - Cargamos las probabilidades de pertenecer a cada clase para imputarlas como nueva columna a la revisión 2.

# %%
Prob_train_without_BG_HB = np.load('Prob_train_review_1_all_features.npy')
Prob_test_without_BG_HB = np.load('Prob_test_review_1_all_features.npy')
Prob_train_1_without_BG_HB_VD_Ins_HOMA = np.load('Prob_train_review_1_without_homa_vit_d.npy')
Prob_test_1_without_BG_HB_VD_Ins_HOMA = np.load('Prob_test_review_1_without_homa_vit_d.npy')

# %% [markdown]
# - **Comprobamos las dimensiones de cada matriz**, tenemos 1317 pacientes para train y 330 para test (partición 80/20).
#
# El 13 hace referencia al número de revisiones que nosotros mismos decicimos como idóneas. 22 son el número de features.

# %%
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)

print(Prob_train_without_BG_HB.shape)  # los nombres de estas variables no son suficientemente claros, debes indicar en algún lado 
#qué diferencia hay entre prob_train y prob_train_1
print(Prob_test_without_BG_HB.shape)
print(Prob_train_1_without_BG_HB_VD_Ins_HOMA.shape)
print(Prob_test_1_without_BG_HB_VD_Ins_HOMA.shape)

#print(Prob_train[0])
#print(Prob_train_1[0])
# Out:
# (1317,)
# (1317, 13, 22)
# (330,)
# (330, 13, 22)
# (1317,)
# (330,)
# (1317,)
# (330,)

# %% [markdown]
# - Como observamos el el histograma, los **datos están desbalanceados**.

# %%
plt.hist(y_train)
plt.show()

# %%
X_train_2 = X_train[:,1,:]

# %% [markdown]
# Vamos a hacer lo siguiente en la función:
#
# 1. Revisar si hay alguna característica que tenga más del 50% a NaN, entonces habría que considerar eliminarla. Tenemos un problema, porque hay que revisar que tengo más de 50% en todas las revisiones. Para no complicar las cosas, vamos a considerar que trabajamos sólo con tres revisiones (vamos a ver si llegamos rápido a ese punto, en otro caso deberíamos ver si paramos en tres revisiones, que ya es bastante).
#
# 1. Revisar si hay algún paciente con más de 8 características NaN, con que esto ocurra en cualquiera de las tres revisiones, deberíamos considerarlo que se elimina, en todas las revisiones.
#
# ## 1.1 Features con problemas:
#
# Revisando la información rápidamente hay varias features con problemas:
#
# 1. **Importante**: las variables *Blood_Glucose* y *Glycated-HB* hay que sacarlas fuera de la base de datos, porque son las que se utilizan para determinar si un pacientes diabético o no.
# 1. Hay cuatro variables que tiene muchos NaN, así que lo que intentaría sería centrarnos en cómo imputarlas, tanto en training como en test. Esto es un poco más complicado de lo que hacemos habitualmente con las bases de datos normales, porque aquí tenemos más datos y de forma un poco más complicada.
#     * HOMA
#     * Insulin
#     * Vitamin-D
#
# Estas son las que más tienen en las tres primeras revisiones. Lo que vamos a hacer es lo siguiente, aprovechando que tenemos un montón de datos y datos temporales vamos a utilizar un esquema diferente para hacer la imputación de forma que sea más razonable, intentando perder el menor número de datos posibles, por ejemplo:
#  * Regresión lineal múltiple con respecto a todas las variables temporales. Otra cosa
#  * Verificar cuál es la correlación entre variables, para una misma revisión, y buscar con las que mayor correlación tengan y proponer un modelo de regresión lineal.
#
# Mi propuesta para el TFG:
#  * Vamos a hacer imputación por la mediana (en el caso de Vitamin-D, HOMA e Insulin) casi seguro que vamos a empeorar un poco porque hay muchos NaN, pero la esperanza es que todo se compense.
#  * Si te ves con fuerzas y ganas probamos lo que he comentado anteriormente

# %%
feature_names = ['Age','Weight','Size','IMC','Creatinine','Cystatin','HDL','LDL','Triglyciredes','GOT','GPT','GGT','Albuminuria','Ferritin','HOMA','Insulin','Blood_Glucose','Glycated-HB','PCR','Vitamin-D','TAS','TAD','Date']
    
df = pd.DataFrame(X_train_2,columns = feature_names[:-1])

# %%
for index,value in enumerate (df.isnull().sum()):
        if value !=0:
            print(df.columns[index],value)
# Out:
# Age 2
# Weight 13
# Size 4
# IMC 15
# Creatinine 5
# Cystatin 141
# HDL 100
# LDL 119
# Triglyciredes 8
# GOT 200
# GPT 8
# GGT 35
# Albuminuria 166
# Ferritin 81
# HOMA 919
# Insulin 903
# Blood_Glucose 3
# Glycated-HB 650
# PCR 132
# Vitamin-D 993

# %%
def data_nan_review_analysis(X):
    """
    Function that takes as input a matrix with pats and features for one review, and gets back
    X_train_rev_imputed,pats_to_drop,feature_to_drop,imputation_data
    """
    feature_names = ['Age','Weight','Size','IMC','Creatinine','Cystatin','HDL','LDL','Triglyciredes','GOT','GPT','GGT','Albuminuria','Ferritin','HOMA','Insulin','Blood_Glucose','Glycated-HB','PCR','Vitamin-D','TAS','TAD','Date']
    
    df = pd.DataFrame(X,columns = feature_names[:-1]) #convert it to df #delete date [:-1]
    
    print(df.columns)
    df = df.drop('Blood_Glucose',axis = 1)
    df = df.drop('Glycated-HB',axis = 1)
    
    
    #initialize vars to return
    X_train_rev_imputed = []
    pats_to_drop = []
    feature_to_drop = []
    imputation_data = []
    #check number of NaNs per feature
    
    for index,value in enumerate (df.isnull().sum()):
        if value !=0:
            print(df.columns[index],value)
            
    #Drop features: Blood_Glucose and Glycated_HB
    

    ##reemplazar cada valor por la mediana 
    
    X_train_rev_imputed = df.fillna(df.median()) 
    
    return X_train_rev_imputed,pats_to_drop,feature_to_drop,imputation_data

def imputing_data(X):
    """ 
    Function that check data with nans and replace them with appropriate imputation
    """
    X_train_aux = X_train.copy()
    num_review = X_train_aux.shape[1]
    
    X_train_imp = []
    
    #run over the reviews and get the X_train_imputed, pats_to_drop, feature_to_drop, and imputation values
    for i in range(3):
        print("review",i)
        print("----------")
        X_train_rev_imputed,pats_to_drop,feature_to_drop,imputation_data = data_nan_review_analysis(X_train_aux[:,i,:])
        print("----------")
        print("----------")
        
        X_train_imp.append(X_train_rev_imputed)
        
    return X_train_imp

# %% [markdown]
# Creamos una nueva variable: **X_train_imp**, obtenida de aplicar la función imputing_data a X_train. Devuelve lo siguiente
#
# - Nº de revisión
# - Features
# - Features con sus respectivos NaN (no aparecen las features eliminadas previamente por la función)

# %%
X_train_sin_NaN_modelo1_rev2_imputing = imputing_data(X_train)
# Out:
# review 0
# ----------
# Index(['Age', 'Weight', 'Size', 'IMC', 'Creatinine', 'Cystatin', 'HDL', 'LDL',
#        'Triglyciredes', 'GOT', 'GPT', 'GGT', 'Albuminuria', 'Ferritin', 'HOMA',
#        'Insulin', 'Blood_Glucose', 'Glycated-HB', 'PCR', 'Vitamin-D', 'TAS',
#        'TAD'],
#       dtype='object')
# Weight 15
# Size 6
# IMC 19
# Creatinine 21
# Cystatin 263
# HDL 115
# LDL 135
# Triglyciredes 24
# GOT 198
# GPT 26
# GGT 54
# Albuminuria 209
# Ferritin 133
# HOMA 958
# Insulin 939
# PCR 231
# Vitamin-D 1079
# ----------
# ----------
# review 1
# ----------
# Index(['Age', 'Weight', 'Size', 'IMC', 'Creatinine', 'Cystatin', 'HDL', 'LDL',
#        'Triglyciredes', 'GOT', 'GPT', 'GGT', 'Albuminuria', 'Ferritin', 'HOMA',
#        'Insulin', 'Blood_Glucose', 'Glycated-HB', 'PCR', 'Vitamin-D', 'TAS',
#        'TAD'],
#       dtype='object')
# Age 2
# Weight 13
# Size 4
# IMC 15
# Creatinine 5
# Cystatin 141
# HDL 100
# LDL 119
# Triglyciredes 8
# GOT 200
# GPT 8
# GGT 35
# Albuminuria 166
# Ferritin 81
# HOMA 919
# Insulin 903
# PCR 132
# Vitamin-D 993
# ----------
# ----------
# review 2
# ----------
# Index(['Age', 'Weight', 'Size', 'IMC', 'Creatinine', 'Cystatin', 'HDL', 'LDL',
#        'Triglyciredes', 'GOT', 'GPT', 'GGT', 'Albuminuria', 'Ferritin', 'HOMA',
#        'Insulin', 'Blood_Glucose', 'Glycated-HB', 'PCR', 'Vitamin-D', 'TAS',
#        'TAD'],
#       dtype='object')
# Age 112
# Weight 121
# Size 112
# IMC 123
# Creatinine 119
# Cystatin 250
# HDL 206
# LDL 227
# Triglyciredes 126
# GOT 338
# GPT 124
# GGT 147
# Albuminuria 276
# Ferritin 186
# HOMA 973
# Insulin 960
# PCR 252
# Vitamin-D 1001
# TAS 109
# TAD 109
# ----------
# ----------

# %% [markdown]
# - Obtenemos las **dos primeras revisiones** ya que nos es más sencillo trabajar. El resultado obtenido será extrapolable a un mayor número de revisiones.

# %%
#Get the second review

X_train_sin_NaN_modelo1_rev2 = X_train_sin_NaN_modelo1_rev2_imputing[1]

# %%
newX_train_modelo1_rev2 = np.concatenate((X_train_sin_NaN_modelo1_rev2, Prob_train_without_BG_HB[:,np.newaxis]), axis=1)
print(newX_train_modelo1_rev2.shape)
# Out:
# (1317, 21)

# %%
newX_train_modelo1_rev2_df = pd.DataFrame(newX_train_modelo1_rev2)

# %% [markdown]
# ### Undersampling:
#
# Las técnicas de *undersampling* eliminan ejemplos del conjunto de datos de entrenamiento que pertenecen a la clase mayoritaria para equilibrar mejor la distribución de clases.
#
# La técnica de submuestreo más simple implica la selección aleatoria de ejemplos de la clase mayoritaria y su eliminación del conjunto de datos de entrenamiento. Esto se conoce como submuestreo aleatorio. Aunque simple y eficaz, una limitación de esta técnica es que los ejemplos se eliminan sin preocuparse por su utilidad o importancia para determinar el límite de decisión entre las clases. Esto significa que es posible, o incluso probable, que se elimine información útil.
#
# Una extensión de este enfoque es ser más exigente con respecto a los ejemplos de la clase mayoritaria que se eliminan. Por lo general, se trata de modelos heurísticos o de aprendizaje que intentan identificar ejemplos redundantes para la eliminación o ejemplos útiles para la no eliminación

# %% [markdown]
# # 2. PREDICCIÓN

# %% [markdown]
# ### 2.1 Random Forest

# %% [markdown]
# Debemos probar una amplia gama de valores y ver qué funciona. Intentaremos ajustar el siguiente conjunto de hiperparámetros:
#
# - max_features = max number of features considered for splitting a node
# - min_samples_split = min number of data points placed in a node before the node is split
# - min_samples_leaf = min number of data points allowed in a leaf node

# %% [markdown]
# Para usar **RandomizedSearchCV**, primero necesitamos crear una cuadrícula de parámetros para muestrear durante el ajuste:

# %%
from sklearn.model_selection import RandomizedSearchCV
# Number of features to consider at every split
max_features = ['auto', 'sqrt','log2']
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4,8,10,12,14,16,18,20]
# Create the random grid
random_grid = {'max_features': max_features,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,}
print(random_grid)
# Out:
# {'max_features': ['auto', 'sqrt', 'log2'], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4, 8, 10, 12, 14, 16, 18, 20]}

# %% [markdown]
# En cada iteración, el algoritmo elegirá una combinación diferente de las características. El beneficio de una búsqueda aleatoria es que no probamos todas las combinaciones, sino que seleccionamos al azar para muestrear una amplia gama de valores.

# %% [markdown]
# **Grid Search**
#
# GridSearchCV es una clase disponible en scikit-learn que permite evaluar y seleccionar de forma sistemática los parámetros de un modelo. Indicándole un modelo y los parámetros a probar, puede evaluar el rendimiento del primero en función de los segundos mediante validación cruzada.
#
# - cv, que es el número de pliegues que se deben usar para la validación cruzada.
#
# Más pliegues de cv reducen las posibilidades de sobreajuste, pero aumentarlo aumentará el tiempo de ejecución.

# %% [markdown]
# **Balanced Random Forest** es una modificación de RF, donde por cada árbol se construyen dos conjuntos bootstrap del mismo tamaño, igual al tamaño de la clase minoritaria: uno para la clase minoritaria, el otro para la clase mayoritaria. Conjuntamente, estos dos conjuntos constituyen el conjunto de entrenamiento.

# %%
# First create the base model to tune

#Creo que es mejor la estrategia que se presenta en from imblearn.ensemble import BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier

rf_1 = BalancedRandomForestClassifier(n_estimators=50, criterion='gini',  
                   bootstrap=True, oob_score=False, class_weight = 'balanced_subsample')

# %%
from sklearn.model_selection import GridSearchCV
# Use the random grid to search for best hyperparameters
# Grid search of parameters, using 7 fold cross validation,

grid_random = GridSearchCV(rf_1, random_grid, cv=7 , n_jobs = 1, verbose = 3)

# %%
# Fit the random search model
grid_random.fit(newX_train_modelo1_rev2_df, y_train)
# Out:
# Fitting 7 folds for each of 90 candidates, totalling 630 fits
# [CV 1/7] END max_features=auto, min_samples_leaf=1, min_samples_split=2;, score=0.688 total time=   0.5s
# [CV 2/7] END max_features=auto, min_samples_leaf=1, min_samples_split=2;, score=0.707 total time=   0.6s
# [CV 3/7] END max_features=auto, min_samples_leaf=1, min_samples_split=2;, score=0.734 total time=   0.5s
# [CV 4/7] END max_features=auto, min_samples_leaf=1, min_samples_split=2;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=1, min_samples_split=2;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=1, min_samples_split=2;, score=0.702 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=1, min_samples_split=2;, score=0.745 total time=   0.5s
# [CV 1/7] END max_features=auto, min_samples_leaf=1, min_samples_split=5;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=1, min_samples_split=5;, score=0.707 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=1, min_samples_split=5;, score=0.713 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=1, min_samples_split=5;, score=0.676 total time=   0.6s
# [CV 5/7] END max_features=auto, min_samples_leaf=1, min_samples_split=5;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=1, min_samples_split=5;, score=0.697 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=1, min_samples_split=5;, score=0.734 total time=   0.4s
# [CV 1/7] END max_features=auto, min_samples_leaf=1, min_samples_split=10;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=1, min_samples_split=10;, score=0.697 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=1, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=1, min_samples_split=10;, score=0.686 total time=   0.5s
# [CV 5/7] END max_features=auto, min_samples_leaf=1, min_samples_split=10;, score=0.702 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=1, min_samples_split=10;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=1, min_samples_split=10;, score=0.729 total time=   0.5s
# [CV 1/7] END max_features=auto, min_samples_leaf=2, min_samples_split=2;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=2, min_samples_split=2;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=2, min_samples_split=2;, score=0.713 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=2, min_samples_split=2;, score=0.676 total time=   0.5s
# [CV 5/7] END max_features=auto, min_samples_leaf=2, min_samples_split=2;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=2, min_samples_split=2;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=2, min_samples_split=2;, score=0.729 total time=   0.4s
# [CV 1/7] END max_features=auto, min_samples_leaf=2, min_samples_split=5;, score=0.672 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=2, min_samples_split=5;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=2, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=2, min_samples_split=5;, score=0.670 total time=   0.5s
# [CV 5/7] END max_features=auto, min_samples_leaf=2, min_samples_split=5;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=2, min_samples_split=5;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=2, min_samples_split=5;, score=0.723 total time=   0.4s
# [CV 1/7] END max_features=auto, min_samples_leaf=2, min_samples_split=10;, score=0.672 total time=   0.5s
# [CV 2/7] END max_features=auto, min_samples_leaf=2, min_samples_split=10;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=2, min_samples_split=10;, score=0.713 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=2, min_samples_split=10;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=2, min_samples_split=10;, score=0.702 total time=   0.5s
# [CV 6/7] END max_features=auto, min_samples_leaf=2, min_samples_split=10;, score=0.697 total time=   0.5s
# [CV 7/7] END max_features=auto, min_samples_leaf=2, min_samples_split=10;, score=0.729 total time=   0.4s
# [CV 1/7] END max_features=auto, min_samples_leaf=4, min_samples_split=2;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=4, min_samples_split=2;, score=0.707 total time=   0.5s
# [CV 3/7] END max_features=auto, min_samples_leaf=4, min_samples_split=2;, score=0.707 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=4, min_samples_split=2;, score=0.691 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=4, min_samples_split=2;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=4, min_samples_split=2;, score=0.691 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=4, min_samples_split=2;, score=0.718 total time=   0.5s
# [CV 1/7] END max_features=auto, min_samples_leaf=4, min_samples_split=5;, score=0.672 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=4, min_samples_split=5;, score=0.697 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=4, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=4, min_samples_split=5;, score=0.686 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=4, min_samples_split=5;, score=0.702 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=4, min_samples_split=5;, score=0.691 total time=   0.5s
# [CV 7/7] END max_features=auto, min_samples_leaf=4, min_samples_split=5;, score=0.718 total time=   0.5s
# [CV 1/7] END max_features=auto, min_samples_leaf=4, min_samples_split=10;, score=0.651 total time=   0.5s
# [CV 2/7] END max_features=auto, min_samples_leaf=4, min_samples_split=10;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=4, min_samples_split=10;, score=0.723 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=4, min_samples_split=10;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=4, min_samples_split=10;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=4, min_samples_split=10;, score=0.686 total time=   0.5s
# [CV 7/7] END max_features=auto, min_samples_leaf=4, min_samples_split=10;, score=0.729 total time=   0.5s
# [CV 1/7] END max_features=auto, min_samples_leaf=8, min_samples_split=2;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=8, min_samples_split=2;, score=0.697 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=8, min_samples_split=2;, score=0.718 total time=   0.5s
# [CV 4/7] END max_features=auto, min_samples_leaf=8, min_samples_split=2;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=8, min_samples_split=2;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=8, min_samples_split=2;, score=0.686 total time=   0.5s
# [CV 7/7] END max_features=auto, min_samples_leaf=8, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=auto, min_samples_leaf=8, min_samples_split=5;, score=0.656 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=8, min_samples_split=5;, score=0.686 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=8, min_samples_split=5;, score=0.707 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=8, min_samples_split=5;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=8, min_samples_split=5;, score=0.707 total time=   0.5s
# [CV 6/7] END max_features=auto, min_samples_leaf=8, min_samples_split=5;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=8, min_samples_split=5;, score=0.723 total time=   0.5s
# [CV 1/7] END max_features=auto, min_samples_leaf=8, min_samples_split=10;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=8, min_samples_split=10;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=8, min_samples_split=10;, score=0.707 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=8, min_samples_split=10;, score=0.676 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=8, min_samples_split=10;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=8, min_samples_split=10;, score=0.691 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=8, min_samples_split=10;, score=0.723 total time=   0.4s
# [CV 1/7] END max_features=auto, min_samples_leaf=10, min_samples_split=2;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=10, min_samples_split=2;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=10, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=10, min_samples_split=2;, score=0.676 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=10, min_samples_split=2;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=10, min_samples_split=2;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=10, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=auto, min_samples_leaf=10, min_samples_split=5;, score=0.656 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=10, min_samples_split=5;, score=0.697 total time=   0.5s
# [CV 3/7] END max_features=auto, min_samples_leaf=10, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=10, min_samples_split=5;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=10, min_samples_split=5;, score=0.723 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=10, min_samples_split=5;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=10, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=auto, min_samples_leaf=10, min_samples_split=10;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=10, min_samples_split=10;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=10, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=10, min_samples_split=10;, score=0.670 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=10, min_samples_split=10;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=10, min_samples_split=10;, score=0.691 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=10, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=auto, min_samples_leaf=12, min_samples_split=2;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=12, min_samples_split=2;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=12, min_samples_split=2;, score=0.713 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=12, min_samples_split=2;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=12, min_samples_split=2;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=12, min_samples_split=2;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=12, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=auto, min_samples_leaf=12, min_samples_split=5;, score=0.672 total time=   0.5s
# [CV 2/7] END max_features=auto, min_samples_leaf=12, min_samples_split=5;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=12, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=12, min_samples_split=5;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=12, min_samples_split=5;, score=0.729 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=12, min_samples_split=5;, score=0.681 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=12, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=auto, min_samples_leaf=12, min_samples_split=10;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=12, min_samples_split=10;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=12, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=12, min_samples_split=10;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=12, min_samples_split=10;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=12, min_samples_split=10;, score=0.686 total time=   0.5s
# [CV 7/7] END max_features=auto, min_samples_leaf=12, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=auto, min_samples_leaf=14, min_samples_split=2;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=14, min_samples_split=2;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=14, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=14, min_samples_split=2;, score=0.691 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=14, min_samples_split=2;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=14, min_samples_split=2;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=14, min_samples_split=2;, score=0.723 total time=   0.4s
# [CV 1/7] END max_features=auto, min_samples_leaf=14, min_samples_split=5;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=14, min_samples_split=5;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=14, min_samples_split=5;, score=0.713 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=14, min_samples_split=5;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=14, min_samples_split=5;, score=0.702 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=14, min_samples_split=5;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=14, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=auto, min_samples_leaf=14, min_samples_split=10;, score=0.651 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=14, min_samples_split=10;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=14, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=14, min_samples_split=10;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=14, min_samples_split=10;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=14, min_samples_split=10;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=14, min_samples_split=10;, score=0.713 total time=   0.4s
# [CV 1/7] END max_features=auto, min_samples_leaf=16, min_samples_split=2;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=16, min_samples_split=2;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=16, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=16, min_samples_split=2;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=16, min_samples_split=2;, score=0.713 total time=   0.5s
# [CV 6/7] END max_features=auto, min_samples_leaf=16, min_samples_split=2;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=16, min_samples_split=2;, score=0.718 total time=   0.5s
# [CV 1/7] END max_features=auto, min_samples_leaf=16, min_samples_split=5;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=16, min_samples_split=5;, score=0.697 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=16, min_samples_split=5;, score=0.713 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=16, min_samples_split=5;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=16, min_samples_split=5;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=16, min_samples_split=5;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=16, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=auto, min_samples_leaf=16, min_samples_split=10;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=16, min_samples_split=10;, score=0.697 total time=   0.5s
# [CV 3/7] END max_features=auto, min_samples_leaf=16, min_samples_split=10;, score=0.713 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=16, min_samples_split=10;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=16, min_samples_split=10;, score=0.713 total time=   0.5s
# [CV 6/7] END max_features=auto, min_samples_leaf=16, min_samples_split=10;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=16, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=auto, min_samples_leaf=18, min_samples_split=2;, score=0.672 total time=   0.5s
# [CV 2/7] END max_features=auto, min_samples_leaf=18, min_samples_split=2;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=18, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=18, min_samples_split=2;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=18, min_samples_split=2;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=18, min_samples_split=2;, score=0.691 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=18, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=auto, min_samples_leaf=18, min_samples_split=5;, score=0.646 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=18, min_samples_split=5;, score=0.686 total time=   0.5s
# [CV 3/7] END max_features=auto, min_samples_leaf=18, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=18, min_samples_split=5;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=18, min_samples_split=5;, score=0.707 total time=   0.5s
# [CV 6/7] END max_features=auto, min_samples_leaf=18, min_samples_split=5;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=18, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=auto, min_samples_leaf=18, min_samples_split=10;, score=0.661 total time=   0.5s
# [CV 2/7] END max_features=auto, min_samples_leaf=18, min_samples_split=10;, score=0.702 total time=   0.5s
# [CV 3/7] END max_features=auto, min_samples_leaf=18, min_samples_split=10;, score=0.713 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=18, min_samples_split=10;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=18, min_samples_split=10;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=18, min_samples_split=10;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=18, min_samples_split=10;, score=0.729 total time=   0.4s
# [CV 1/7] END max_features=auto, min_samples_leaf=20, min_samples_split=2;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=20, min_samples_split=2;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=auto, min_samples_leaf=20, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=20, min_samples_split=2;, score=0.676 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=20, min_samples_split=2;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=20, min_samples_split=2;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=20, min_samples_split=2;, score=0.718 total time=   0.5s
# [CV 1/7] END max_features=auto, min_samples_leaf=20, min_samples_split=5;, score=0.672 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=20, min_samples_split=5;, score=0.702 total time=   0.5s
# [CV 3/7] END max_features=auto, min_samples_leaf=20, min_samples_split=5;, score=0.718 total time=   0.5s
# [CV 4/7] END max_features=auto, min_samples_leaf=20, min_samples_split=5;, score=0.670 total time=   0.5s
# [CV 5/7] END max_features=auto, min_samples_leaf=20, min_samples_split=5;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=20, min_samples_split=5;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=20, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=auto, min_samples_leaf=20, min_samples_split=10;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=auto, min_samples_leaf=20, min_samples_split=10;, score=0.707 total time=   0.5s
# [CV 3/7] END max_features=auto, min_samples_leaf=20, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=auto, min_samples_leaf=20, min_samples_split=10;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=auto, min_samples_leaf=20, min_samples_split=10;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=auto, min_samples_leaf=20, min_samples_split=10;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=auto, min_samples_leaf=20, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=1, min_samples_split=2;, score=0.667 total time=   0.5s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=1, min_samples_split=2;, score=0.691 total time=   0.4s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=1, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=1, min_samples_split=2;, score=0.691 total time=   0.4s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=1, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=1, min_samples_split=2;, score=0.702 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=1, min_samples_split=2;, score=0.729 total time=   0.5s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=1, min_samples_split=5;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=1, min_samples_split=5;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=1, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=1, min_samples_split=5;, score=0.691 total time=   0.4s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=1, min_samples_split=5;, score=0.697 total time=   0.4s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=1, min_samples_split=5;, score=0.697 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=1, min_samples_split=5;, score=0.734 total time=   0.4s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=1, min_samples_split=10;, score=0.672 total time=   0.5s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=1, min_samples_split=10;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=1, min_samples_split=10;, score=0.723 total time=   0.4s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=1, min_samples_split=10;, score=0.686 total time=   0.4s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=1, min_samples_split=10;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=1, min_samples_split=10;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=1, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=2, min_samples_split=2;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=2, min_samples_split=2;, score=0.702 total time=   0.5s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=2, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=2, min_samples_split=2;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=2, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=2, min_samples_split=2;, score=0.681 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=2, min_samples_split=2;, score=0.729 total time=   0.4s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=2, min_samples_split=5;, score=0.651 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=2, min_samples_split=5;, score=0.697 total time=   0.4s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=2, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=2, min_samples_split=5;, score=0.670 total time=   0.4s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=2, min_samples_split=5;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=2, min_samples_split=5;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=2, min_samples_split=5;, score=0.723 total time=   0.4s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=2, min_samples_split=10;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=2, min_samples_split=10;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=2, min_samples_split=10;, score=0.723 total time=   0.4s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=2, min_samples_split=10;, score=0.686 total time=   0.4s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=2, min_samples_split=10;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=2, min_samples_split=10;, score=0.713 total time=   0.5s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=2, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=4, min_samples_split=2;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=4, min_samples_split=2;, score=0.707 total time=   0.4s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=4, min_samples_split=2;, score=0.707 total time=   0.4s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=4, min_samples_split=2;, score=0.676 total time=   0.4s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=4, min_samples_split=2;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=4, min_samples_split=2;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=4, min_samples_split=2;, score=0.729 total time=   0.5s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=4, min_samples_split=5;, score=0.656 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=4, min_samples_split=5;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=4, min_samples_split=5;, score=0.723 total time=   0.4s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=4, min_samples_split=5;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=4, min_samples_split=5;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=4, min_samples_split=5;, score=0.691 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=4, min_samples_split=5;, score=0.718 total time=   0.5s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=4, min_samples_split=10;, score=0.672 total time=   0.5s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=4, min_samples_split=10;, score=0.691 total time=   0.4s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=4, min_samples_split=10;, score=0.734 total time=   0.4s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=4, min_samples_split=10;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=4, min_samples_split=10;, score=0.713 total time=   0.5s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=4, min_samples_split=10;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=4, min_samples_split=10;, score=0.734 total time=   0.4s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=8, min_samples_split=2;, score=0.672 total time=   0.6s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=8, min_samples_split=2;, score=0.702 total time=   0.6s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=8, min_samples_split=2;, score=0.723 total time=   0.6s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=8, min_samples_split=2;, score=0.686 total time=   0.5s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=8, min_samples_split=2;, score=0.707 total time=   0.5s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=8, min_samples_split=2;, score=0.691 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=8, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.702 total time=   0.5s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.718 total time=   0.6s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.681 total time=   0.7s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.707 total time=   0.6s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.691 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=8, min_samples_split=5;, score=0.718 total time=   0.5s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=8, min_samples_split=10;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=8, min_samples_split=10;, score=0.697 total time=   0.4s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=8, min_samples_split=10;, score=0.718 total time=   0.5s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=8, min_samples_split=10;, score=0.676 total time=   0.5s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=8, min_samples_split=10;, score=0.713 total time=   0.5s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=8, min_samples_split=10;, score=0.686 total time=   0.5s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=8, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=10, min_samples_split=2;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=10, min_samples_split=2;, score=0.707 total time=   0.4s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=10, min_samples_split=2;, score=0.723 total time=   0.4s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=10, min_samples_split=2;, score=0.686 total time=   0.4s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=10, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=10, min_samples_split=2;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=10, min_samples_split=2;, score=0.723 total time=   0.5s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=10, min_samples_split=5;, score=0.672 total time=   0.6s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=10, min_samples_split=5;, score=0.702 total time=   0.6s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=10, min_samples_split=5;, score=0.718 total time=   0.6s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=10, min_samples_split=5;, score=0.686 total time=   0.5s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=10, min_samples_split=5;, score=0.707 total time=   0.5s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=10, min_samples_split=5;, score=0.686 total time=   0.5s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=10, min_samples_split=5;, score=0.718 total time=   0.6s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=10, min_samples_split=10;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=10, min_samples_split=10;, score=0.702 total time=   0.5s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=10, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=10, min_samples_split=10;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=10, min_samples_split=10;, score=0.707 total time=   0.5s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=10, min_samples_split=10;, score=0.686 total time=   0.5s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=10, min_samples_split=10;, score=0.729 total time=   0.4s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=12, min_samples_split=2;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=12, min_samples_split=2;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=12, min_samples_split=2;, score=0.718 total time=   0.5s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=12, min_samples_split=2;, score=0.676 total time=   0.5s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=12, min_samples_split=2;, score=0.702 total time=   0.5s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=12, min_samples_split=2;, score=0.686 total time=   0.5s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=12, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=12, min_samples_split=5;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=12, min_samples_split=5;, score=0.702 total time=   0.5s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=12, min_samples_split=5;, score=0.713 total time=   0.5s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=12, min_samples_split=5;, score=0.686 total time=   0.5s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=12, min_samples_split=5;, score=0.713 total time=   0.5s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=12, min_samples_split=5;, score=0.686 total time=   0.5s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=12, min_samples_split=5;, score=0.718 total time=   0.7s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=12, min_samples_split=10;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=12, min_samples_split=10;, score=0.702 total time=   0.6s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=12, min_samples_split=10;, score=0.718 total time=   0.7s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=12, min_samples_split=10;, score=0.686 total time=   0.6s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=12, min_samples_split=10;, score=0.713 total time=   0.6s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=12, min_samples_split=10;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=12, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=14, min_samples_split=2;, score=0.651 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=14, min_samples_split=2;, score=0.702 total time=   0.5s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=14, min_samples_split=2;, score=0.718 total time=   0.5s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=14, min_samples_split=2;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=14, min_samples_split=2;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=14, min_samples_split=2;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=14, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=14, min_samples_split=5;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=14, min_samples_split=5;, score=0.713 total time=   0.4s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=14, min_samples_split=5;, score=0.723 total time=   0.5s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=14, min_samples_split=5;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=14, min_samples_split=5;, score=0.707 total time=   0.5s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=14, min_samples_split=5;, score=0.686 total time=   0.5s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=14, min_samples_split=5;, score=0.729 total time=   0.4s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=14, min_samples_split=10;, score=0.672 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=14, min_samples_split=10;, score=0.702 total time=   0.5s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=14, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=14, min_samples_split=10;, score=0.681 total time=   0.5s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=14, min_samples_split=10;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=14, min_samples_split=10;, score=0.686 total time=   0.5s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=14, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=16, min_samples_split=2;, score=0.667 total time=   0.5s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=16, min_samples_split=2;, score=0.697 total time=   0.5s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=16, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=16, min_samples_split=2;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=16, min_samples_split=2;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=16, min_samples_split=2;, score=0.691 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=16, min_samples_split=2;, score=0.723 total time=   0.4s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=16, min_samples_split=5;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=16, min_samples_split=5;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=16, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=16, min_samples_split=5;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=16, min_samples_split=5;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=16, min_samples_split=5;, score=0.697 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=16, min_samples_split=5;, score=0.718 total time=   0.5s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=16, min_samples_split=10;, score=0.656 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=16, min_samples_split=10;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=16, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=16, min_samples_split=10;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=16, min_samples_split=10;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=16, min_samples_split=10;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=16, min_samples_split=10;, score=0.723 total time=   0.5s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=18, min_samples_split=2;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=18, min_samples_split=2;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=18, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=18, min_samples_split=2;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=18, min_samples_split=2;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=18, min_samples_split=2;, score=0.691 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=18, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=18, min_samples_split=5;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=18, min_samples_split=5;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=18, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=18, min_samples_split=5;, score=0.670 total time=   0.4s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=18, min_samples_split=5;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=18, min_samples_split=5;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=18, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=18, min_samples_split=10;, score=0.656 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=18, min_samples_split=10;, score=0.702 total time=   0.5s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=18, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=18, min_samples_split=10;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=18, min_samples_split=10;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=18, min_samples_split=10;, score=0.681 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=18, min_samples_split=10;, score=0.723 total time=   0.4s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=20, min_samples_split=2;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=20, min_samples_split=2;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=20, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=20, min_samples_split=2;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=20, min_samples_split=2;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=20, min_samples_split=2;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=20, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=20, min_samples_split=5;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=20, min_samples_split=5;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=20, min_samples_split=5;, score=0.729 total time=   0.4s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=20, min_samples_split=5;, score=0.686 total time=   0.4s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=20, min_samples_split=5;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=20, min_samples_split=5;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=20, min_samples_split=5;, score=0.723 total time=   0.4s
# [CV 1/7] END max_features=sqrt, min_samples_leaf=20, min_samples_split=10;, score=0.656 total time=   0.4s
# [CV 2/7] END max_features=sqrt, min_samples_leaf=20, min_samples_split=10;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=sqrt, min_samples_leaf=20, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=sqrt, min_samples_leaf=20, min_samples_split=10;, score=0.681 total time=   0.5s
# [CV 5/7] END max_features=sqrt, min_samples_leaf=20, min_samples_split=10;, score=0.713 total time=   0.5s
# [CV 6/7] END max_features=sqrt, min_samples_leaf=20, min_samples_split=10;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=sqrt, min_samples_leaf=20, min_samples_split=10;, score=0.713 total time=   0.4s
# [CV 1/7] END max_features=log2, min_samples_leaf=1, min_samples_split=2;, score=0.672 total time=   0.5s
# [CV 2/7] END max_features=log2, min_samples_leaf=1, min_samples_split=2;, score=0.713 total time=   0.4s
# [CV 3/7] END max_features=log2, min_samples_leaf=1, min_samples_split=2;, score=0.729 total time=   0.4s
# [CV 4/7] END max_features=log2, min_samples_leaf=1, min_samples_split=2;, score=0.686 total time=   0.4s
# [CV 5/7] END max_features=log2, min_samples_leaf=1, min_samples_split=2;, score=0.697 total time=   0.4s
# [CV 6/7] END max_features=log2, min_samples_leaf=1, min_samples_split=2;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=log2, min_samples_leaf=1, min_samples_split=2;, score=0.739 total time=   0.4s
# [CV 1/7] END max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=0.677 total time=   0.4s
# [CV 2/7] END max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=0.713 total time=   0.4s
# [CV 4/7] END max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=0.686 total time=   0.4s
# [CV 5/7] END max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=0.723 total time=   0.4s
# [CV 1/7] END max_features=log2, min_samples_leaf=1, min_samples_split=10;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=log2, min_samples_leaf=1, min_samples_split=10;, score=0.702 total time=   0.5s
# [CV 3/7] END max_features=log2, min_samples_leaf=1, min_samples_split=10;, score=0.739 total time=   0.5s
# [CV 4/7] END max_features=log2, min_samples_leaf=1, min_samples_split=10;, score=0.713 total time=   0.4s
# [CV 5/7] END max_features=log2, min_samples_leaf=1, min_samples_split=10;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=log2, min_samples_leaf=1, min_samples_split=10;, score=0.691 total time=   0.4s
# [CV 7/7] END max_features=log2, min_samples_leaf=1, min_samples_split=10;, score=0.723 total time=   0.4s
# [CV 1/7] END max_features=log2, min_samples_leaf=2, min_samples_split=2;, score=0.651 total time=   0.4s
# [CV 2/7] END max_features=log2, min_samples_leaf=2, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 3/7] END max_features=log2, min_samples_leaf=2, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=log2, min_samples_leaf=2, min_samples_split=2;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=log2, min_samples_leaf=2, min_samples_split=2;, score=0.707 total time=   0.5s
# [CV 6/7] END max_features=log2, min_samples_leaf=2, min_samples_split=2;, score=0.697 total time=   0.5s
# [CV 7/7] END max_features=log2, min_samples_leaf=2, min_samples_split=2;, score=0.718 total time=   0.5s
# [CV 1/7] END max_features=log2, min_samples_leaf=2, min_samples_split=5;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=log2, min_samples_leaf=2, min_samples_split=5;, score=0.713 total time=   0.4s
# [CV 3/7] END max_features=log2, min_samples_leaf=2, min_samples_split=5;, score=0.713 total time=   0.5s
# [CV 4/7] END max_features=log2, min_samples_leaf=2, min_samples_split=5;, score=0.681 total time=   0.4s
# ...
# [CV 2/7] END max_features=log2, min_samples_leaf=8, min_samples_split=2;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=log2, min_samples_leaf=8, min_samples_split=2;, score=0.723 total time=   0.4s
# [CV 4/7] END max_features=log2, min_samples_leaf=8, min_samples_split=2;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=log2, min_samples_leaf=8, min_samples_split=2;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=log2, min_samples_leaf=8, min_samples_split=2;, score=0.686 total time=   0.5s
# [CV 7/7] END max_features=log2, min_samples_leaf=8, min_samples_split=2;, score=0.723 total time=   0.4s
# [CV 1/7] END max_features=log2, min_samples_leaf=8, min_samples_split=5;, score=0.672 total time=   0.4s
# [CV 2/7] END max_features=log2, min_samples_leaf=8, min_samples_split=5;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=log2, min_samples_leaf=8, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=log2, min_samples_leaf=8, min_samples_split=5;, score=0.670 total time=   0.4s
# [CV 5/7] END max_features=log2, min_samples_leaf=8, min_samples_split=5;, score=0.713 total time=   0.5s
# [CV 6/7] END max_features=log2, min_samples_leaf=8, min_samples_split=5;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=log2, min_samples_leaf=8, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=log2, min_samples_leaf=8, min_samples_split=10;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=log2, min_samples_leaf=8, min_samples_split=10;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=log2, min_samples_leaf=8, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=log2, min_samples_leaf=8, min_samples_split=10;, score=0.691 total time=   0.5s
# [CV 5/7] END max_features=log2, min_samples_leaf=8, min_samples_split=10;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=log2, min_samples_leaf=8, min_samples_split=10;, score=0.681 total time=   0.4s
# [CV 7/7] END max_features=log2, min_samples_leaf=8, min_samples_split=10;, score=0.723 total time=   0.4s
# [CV 1/7] END max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=0.702 total time=   0.5s
# [CV 3/7] END max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=0.718 total time=   0.5s
# [CV 4/7] END max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=0.676 total time=   0.4s
# [CV 5/7] END max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=0.697 total time=   0.4s
# [CV 3/7] END max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=0.729 total time=   0.4s
# [CV 4/7] END max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=0.686 total time=   0.4s
# [CV 5/7] END max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=0.691 total time=   0.4s
# [CV 7/7] END max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=0.729 total time=   0.4s
# [CV 1/7] END max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=0.656 total time=   0.4s
# [CV 2/7] END max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=0.697 total time=   0.4s
# [CV 3/7] END max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=0.713 total time=   0.4s
# [CV 4/7] END max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=0.723 total time=   0.4s
# [CV 1/7] END max_features=log2, min_samples_leaf=12, min_samples_split=2;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=log2, min_samples_leaf=12, min_samples_split=2;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=log2, min_samples_leaf=12, min_samples_split=2;, score=0.702 total time=   0.4s
# [CV 4/7] END max_features=log2, min_samples_leaf=12, min_samples_split=2;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=log2, min_samples_leaf=12, min_samples_split=2;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=log2, min_samples_leaf=12, min_samples_split=2;, score=0.691 total time=   0.4s
# [CV 7/7] END max_features=log2, min_samples_leaf=12, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=log2, min_samples_leaf=12, min_samples_split=5;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=log2, min_samples_leaf=12, min_samples_split=5;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=log2, min_samples_leaf=12, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=log2, min_samples_leaf=12, min_samples_split=5;, score=0.676 total time=   0.4s
# [CV 5/7] END max_features=log2, min_samples_leaf=12, min_samples_split=5;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=log2, min_samples_leaf=12, min_samples_split=5;, score=0.697 total time=   0.4s
# [CV 7/7] END max_features=log2, min_samples_leaf=12, min_samples_split=5;, score=0.723 total time=   0.4s
# [CV 1/7] END max_features=log2, min_samples_leaf=12, min_samples_split=10;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=log2, min_samples_leaf=12, min_samples_split=10;, score=0.686 total time=   0.4s
# [CV 3/7] END max_features=log2, min_samples_leaf=12, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=log2, min_samples_leaf=12, min_samples_split=10;, score=0.670 total time=   0.4s
# [CV 5/7] END max_features=log2, min_samples_leaf=12, min_samples_split=10;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=log2, min_samples_leaf=12, min_samples_split=10;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=log2, min_samples_leaf=12, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=log2, min_samples_leaf=14, min_samples_split=2;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=log2, min_samples_leaf=14, min_samples_split=2;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=log2, min_samples_leaf=14, min_samples_split=2;, score=0.713 total time=   0.4s
# [CV 4/7] END max_features=log2, min_samples_leaf=14, min_samples_split=2;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=log2, min_samples_leaf=14, min_samples_split=2;, score=0.702 total time=   0.4s
# [CV 6/7] END max_features=log2, min_samples_leaf=14, min_samples_split=2;, score=0.691 total time=   0.5s
# [CV 7/7] END max_features=log2, min_samples_leaf=14, min_samples_split=2;, score=0.718 total time=   0.5s
# [CV 1/7] END max_features=log2, min_samples_leaf=14, min_samples_split=5;, score=0.667 total time=   0.5s
# [CV 2/7] END max_features=log2, min_samples_leaf=14, min_samples_split=5;, score=0.707 total time=   0.5s
# [CV 3/7] END max_features=log2, min_samples_leaf=14, min_samples_split=5;, score=0.718 total time=   0.5s
# [CV 4/7] END max_features=log2, min_samples_leaf=14, min_samples_split=5;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=log2, min_samples_leaf=14, min_samples_split=5;, score=0.713 total time=   0.4s
# [CV 6/7] END max_features=log2, min_samples_leaf=14, min_samples_split=5;, score=0.691 total time=   0.4s
# [CV 7/7] END max_features=log2, min_samples_leaf=14, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=log2, min_samples_leaf=14, min_samples_split=10;, score=0.672 total time=   0.5s
# [CV 2/7] END max_features=log2, min_samples_leaf=14, min_samples_split=10;, score=0.697 total time=   0.4s
# [CV 3/7] END max_features=log2, min_samples_leaf=14, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=log2, min_samples_leaf=14, min_samples_split=10;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=log2, min_samples_leaf=14, min_samples_split=10;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=log2, min_samples_leaf=14, min_samples_split=10;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=log2, min_samples_leaf=14, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=log2, min_samples_leaf=16, min_samples_split=2;, score=0.640 total time=   0.4s
# [CV 2/7] END max_features=log2, min_samples_leaf=16, min_samples_split=2;, score=0.707 total time=   0.4s
# [CV 3/7] END max_features=log2, min_samples_leaf=16, min_samples_split=2;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=log2, min_samples_leaf=16, min_samples_split=2;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=log2, min_samples_leaf=16, min_samples_split=2;, score=0.723 total time=   0.4s
# [CV 6/7] END max_features=log2, min_samples_leaf=16, min_samples_split=2;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=log2, min_samples_leaf=16, min_samples_split=2;, score=0.723 total time=   0.4s
# [CV 1/7] END max_features=log2, min_samples_leaf=16, min_samples_split=5;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=log2, min_samples_leaf=16, min_samples_split=5;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=log2, min_samples_leaf=16, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=log2, min_samples_leaf=16, min_samples_split=5;, score=0.676 total time=   0.4s
# [CV 5/7] END max_features=log2, min_samples_leaf=16, min_samples_split=5;, score=0.707 total time=   0.5s
# [CV 6/7] END max_features=log2, min_samples_leaf=16, min_samples_split=5;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=log2, min_samples_leaf=16, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=log2, min_samples_leaf=16, min_samples_split=10;, score=0.667 total time=   0.4s
# [CV 2/7] END max_features=log2, min_samples_leaf=16, min_samples_split=10;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=log2, min_samples_leaf=16, min_samples_split=10;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=log2, min_samples_leaf=16, min_samples_split=10;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=log2, min_samples_leaf=16, min_samples_split=10;, score=0.718 total time=   0.5s
# [CV 6/7] END max_features=log2, min_samples_leaf=16, min_samples_split=10;, score=0.681 total time=   0.5s
# [CV 7/7] END max_features=log2, min_samples_leaf=16, min_samples_split=10;, score=0.718 total time=   0.5s
# [CV 1/7] END max_features=log2, min_samples_leaf=18, min_samples_split=2;, score=0.667 total time=   0.5s
# [CV 2/7] END max_features=log2, min_samples_leaf=18, min_samples_split=2;, score=0.702 total time=   0.5s
# [CV 3/7] END max_features=log2, min_samples_leaf=18, min_samples_split=2;, score=0.713 total time=   0.5s
# [CV 4/7] END max_features=log2, min_samples_leaf=18, min_samples_split=2;, score=0.681 total time=   0.5s
# [CV 5/7] END max_features=log2, min_samples_leaf=18, min_samples_split=2;, score=0.718 total time=   0.6s
# [CV 6/7] END max_features=log2, min_samples_leaf=18, min_samples_split=2;, score=0.686 total time=   0.5s
# [CV 7/7] END max_features=log2, min_samples_leaf=18, min_samples_split=2;, score=0.718 total time=   0.5s
# [CV 1/7] END max_features=log2, min_samples_leaf=18, min_samples_split=5;, score=0.667 total time=   0.6s
# [CV 2/7] END max_features=log2, min_samples_leaf=18, min_samples_split=5;, score=0.702 total time=   0.5s
# [CV 3/7] END max_features=log2, min_samples_leaf=18, min_samples_split=5;, score=0.718 total time=   0.5s
# [CV 4/7] END max_features=log2, min_samples_leaf=18, min_samples_split=5;, score=0.681 total time=   0.5s
# [CV 5/7] END max_features=log2, min_samples_leaf=18, min_samples_split=5;, score=0.702 total time=   0.4s
# [CV 6/7] END max_features=log2, min_samples_leaf=18, min_samples_split=5;, score=0.697 total time=   0.4s
# [CV 7/7] END max_features=log2, min_samples_leaf=18, min_samples_split=5;, score=0.718 total time=   0.5s
# [CV 1/7] END max_features=log2, min_samples_leaf=18, min_samples_split=10;, score=0.672 total time=   0.5s
# [CV 2/7] END max_features=log2, min_samples_leaf=18, min_samples_split=10;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=log2, min_samples_leaf=18, min_samples_split=10;, score=0.718 total time=   0.5s
# [CV 4/7] END max_features=log2, min_samples_leaf=18, min_samples_split=10;, score=0.681 total time=   0.5s
# [CV 5/7] END max_features=log2, min_samples_leaf=18, min_samples_split=10;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=log2, min_samples_leaf=18, min_samples_split=10;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=log2, min_samples_leaf=18, min_samples_split=10;, score=0.723 total time=   0.4s
# [CV 1/7] END max_features=log2, min_samples_leaf=20, min_samples_split=2;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=log2, min_samples_leaf=20, min_samples_split=2;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=log2, min_samples_leaf=20, min_samples_split=2;, score=0.718 total time=   0.6s
# [CV 4/7] END max_features=log2, min_samples_leaf=20, min_samples_split=2;, score=0.681 total time=   0.5s
# [CV 5/7] END max_features=log2, min_samples_leaf=20, min_samples_split=2;, score=0.713 total time=   0.5s
# [CV 6/7] END max_features=log2, min_samples_leaf=20, min_samples_split=2;, score=0.686 total time=   0.5s
# [CV 7/7] END max_features=log2, min_samples_leaf=20, min_samples_split=2;, score=0.718 total time=   0.5s
# [CV 1/7] END max_features=log2, min_samples_leaf=20, min_samples_split=5;, score=0.635 total time=   0.5s
# [CV 2/7] END max_features=log2, min_samples_leaf=20, min_samples_split=5;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=log2, min_samples_leaf=20, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 4/7] END max_features=log2, min_samples_leaf=20, min_samples_split=5;, score=0.681 total time=   0.5s
# [CV 5/7] END max_features=log2, min_samples_leaf=20, min_samples_split=5;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=log2, min_samples_leaf=20, min_samples_split=5;, score=0.686 total time=   0.4s
# [CV 7/7] END max_features=log2, min_samples_leaf=20, min_samples_split=5;, score=0.718 total time=   0.4s
# [CV 1/7] END max_features=log2, min_samples_leaf=20, min_samples_split=10;, score=0.661 total time=   0.4s
# [CV 2/7] END max_features=log2, min_samples_leaf=20, min_samples_split=10;, score=0.702 total time=   0.4s
# [CV 3/7] END max_features=log2, min_samples_leaf=20, min_samples_split=10;, score=0.718 total time=   0.5s
# [CV 4/7] END max_features=log2, min_samples_leaf=20, min_samples_split=10;, score=0.681 total time=   0.4s
# [CV 5/7] END max_features=log2, min_samples_leaf=20, min_samples_split=10;, score=0.707 total time=   0.4s
# [CV 6/7] END max_features=log2, min_samples_leaf=20, min_samples_split=10;, score=0.686 total time=   0.5s
# [CV 7/7] END max_features=log2, min_samples_leaf=20, min_samples_split=10;, score=0.718 total time=   0.4s
# GridSearchCV(cv=7,
#              estimator=BalancedRandomForestClassifier(class_weight='balanced_subsample',
#                                                       n_estimators=50),
#              n_jobs=1,
#              param_grid={'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4, 8, 10, 12, 14, 16, 18,
#                                               20],
#                          'min_samples_split': [2, 5, 10]},
#              verbose=3)

# %%
grid_random.best_params_
# Out:
# {'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}

# %% [markdown]
# Creamos un **nuevo modelo** teniendo en cuenta los hiperparámetros que nos devuelve Grid_Search

# %%
rf_2 = BalancedRandomForestClassifier(n_estimators=5000, criterion='gini', max_features = grid_random.best_params_['max_features'],
                min_samples_leaf = grid_random.best_params_['min_samples_leaf'], min_samples_split = grid_random.best_params_['min_samples_split'],    
                   bootstrap=True, oob_score=False, class_weight = 'balanced_subsample',n_jobs=-1,verbose = 3)

# %%
rf_2.fit(newX_train_modelo1_rev2_df, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# building tree 1 of 5000building tree 4 of 5000
#
# building tree 2 of 5000
# building tree 3 of 5000
# building tree 5 of 5000
# building tree 6 of 5000
# building tree 7 of 5000
# building tree 8 of 5000
# building tree 10 of 5000
# building tree 9 of 5000
# building tree 11 of 5000
# building tree 15 of 5000building tree 14 of 5000
#
# building tree 12 of 5000
# building tree 13 of 5000
# building tree 16 of 5000
# building tree 17 of 5000
# building tree 18 of 5000
# building tree 19 of 5000
# building tree 21 of 5000building tree 20 of 5000
#
# building tree 22 of 5000
# building tree 24 of 5000
# building tree 23 of 5000
# building tree 25 of 5000
# building tree 26 of 5000
# building tree 28 of 5000building tree 27 of 5000
#
# building tree 29 of 5000
# building tree 30 of 5000
# building tree 31 of 5000
# building tree 32 of 5000
# building tree 33 of 5000
# building tree 34 of 5000
# building tree 36 of 5000building tree 35 of 5000
#
# building tree 37 of 5000building tree 38 of 5000
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.2s
# building tree 39 of 5000
# building tree 40 of 5000
# building tree 41 of 5000
# building tree 42 of 5000
# building tree 44 of 5000building tree 43 of 5000
#
# building tree 45 of 5000
# building tree 46 of 5000
# building tree 47 of 5000
# building tree 48 of 5000
# building tree 49 of 5000
# building tree 50 of 5000
# building tree 51 of 5000
# building tree 52 of 5000
# building tree 53 of 5000
# building tree 54 of 5000
# building tree 55 of 5000
# building tree 56 of 5000
# building tree 57 of 5000
# building tree 58 of 5000
# building tree 59 of 5000
# building tree 60 of 5000
# building tree 61 of 5000
# building tree 62 of 5000
# building tree 63 of 5000
# building tree 64 of 5000
# building tree 65 of 5000
# building tree 66 of 5000building tree 67 of 5000
#
# building tree 68 of 5000
# building tree 69 of 5000
# building tree 70 of 5000
# building tree 71 of 5000
# building tree 73 of 5000
# building tree 72 of 5000
# building tree 74 of 5000
# building tree 75 of 5000building tree 76 of 5000
# building tree 77 of 5000
#
# building tree 78 of 5000
# building tree 80 of 5000
# building tree 79 of 5000
# building tree 81 of 5000
# building tree 82 of 5000
# building tree 84 of 5000building tree 83 of 5000
#
# building tree 85 of 5000
# building tree 86 of 5000building tree 87 of 5000
#
# building tree 88 of 5000
# building tree 89 of 5000
# building tree 91 of 5000
# building tree 90 of 5000
# building tree 92 of 5000
# building tree 93 of 5000
# building tree 94 of 5000
# building tree 95 of 5000
# building tree 96 of 5000
# building tree 97 of 5000
# building tree 99 of 5000building tree 98 of 5000
#
# building tree 100 of 5000
# building tree 101 of 5000
# building tree 102 of 5000
# building tree 103 of 5000
# building tree 104 of 5000
# building tree 105 of 5000
# building tree 106 of 5000
# building tree 107 of 5000
# building tree 108 of 5000
# building tree 109 of 5000
# building tree 110 of 5000building tree 111 of 5000
#
# building tree 112 of 5000
# building tree 113 of 5000
# building tree 116 of 5000
# building tree 115 of 5000
# building tree 114 of 5000
# building tree 118 of 5000
# building tree 120 of 5000
# building tree 119 of 5000
# building tree 117 of 5000
# building tree 123 of 5000
# building tree 122 of 5000
# building tree 121 of 5000
# building tree 124 of 5000
# building tree 125 of 5000
# building tree 126 of 5000
# building tree 127 of 5000
# building tree 128 of 5000
# building tree 129 of 5000
# building tree 130 of 5000
# building tree 131 of 5000
# building tree 132 of 5000
# building tree 133 of 5000
# building tree 134 of 5000
# building tree 135 of 5000
# building tree 136 of 5000
# building tree 137 of 5000
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:    1.2s
# building tree 138 of 5000
# building tree 139 of 5000
# building tree 141 of 5000
# building tree 140 of 5000
# building tree 142 of 5000
# building tree 143 of 5000
# building tree 145 of 5000
# building tree 144 of 5000
# building tree 146 of 5000
# building tree 147 of 5000
# building tree 148 of 5000building tree 149 of 5000
# building tree 150 of 5000
#
# building tree 151 of 5000
# building tree 154 of 5000
# building tree 153 of 5000
# building tree 152 of 5000
# building tree 156 of 5000
# building tree 155 of 5000
# building tree 157 of 5000
# building tree 158 of 5000
# building tree 159 of 5000
# building tree 160 of 5000
# building tree 161 of 5000
# building tree 162 of 5000
# building tree 163 of 5000building tree 165 of 5000
#
# building tree 164 of 5000
# building tree 166 of 5000
# building tree 167 of 5000
# building tree 168 of 5000
# building tree 169 of 5000
# building tree 170 of 5000
# building tree 171 of 5000
# building tree 172 of 5000building tree 173 of 5000
#
# building tree 174 of 5000
# building tree 175 of 5000
# building tree 176 of 5000
# building tree 178 of 5000
# building tree 177 of 5000
# building tree 179 of 5000
# building tree 180 of 5000
# building tree 181 of 5000
# building tree 182 of 5000
# building tree 183 of 5000
# building tree 184 of 5000
# building tree 187 of 5000building tree 186 of 5000
#
# building tree 185 of 5000
# building tree 188 of 5000
# building tree 189 of 5000
# building tree 190 of 5000
# building tree 191 of 5000
# building tree 192 of 5000
# building tree 193 of 5000
# building tree 194 of 5000
# building tree 195 of 5000
# building tree 196 of 5000building tree 197 of 5000
#
# building tree 199 of 5000building tree 198 of 5000
#
# building tree 200 of 5000
# building tree 201 of 5000
# building tree 202 of 5000
# building tree 203 of 5000
# building tree 206 of 5000building tree 205 of 5000
# building tree 204 of 5000
#
# building tree 207 of 5000
# building tree 208 of 5000
# building tree 210 of 5000
# building tree 209 of 5000
# building tree 212 of 5000
# building tree 211 of 5000
# building tree 213 of 5000
# building tree 214 of 5000
# building tree 215 of 5000
# building tree 216 of 5000
# building tree 218 of 5000
# building tree 217 of 5000
# building tree 219 of 5000
# building tree 221 of 5000
# building tree 222 of 5000
# building tree 220 of 5000
# building tree 223 of 5000
# building tree 224 of 5000
# building tree 225 of 5000
# building tree 226 of 5000
# building tree 227 of 5000
# building tree 228 of 5000
# building tree 230 of 5000building tree 229 of 5000
#
# building tree 231 of 5000building tree 232 of 5000
#
# building tree 233 of 5000
# building tree 234 of 5000
# building tree 235 of 5000
# building tree 236 of 5000
# building tree 237 of 5000building tree 238 of 5000
#
# building tree 240 of 5000
# building tree 239 of 5000
# building tree 241 of 5000
# building tree 242 of 5000
# building tree 243 of 5000
# building tree 244 of 5000
# building tree 245 of 5000
# building tree 246 of 5000
# building tree 247 of 5000
# building tree 248 of 5000
# building tree 249 of 5000
# building tree 250 of 5000
# building tree 251 of 5000
# building tree 252 of 5000
# building tree 253 of 5000building tree 255 of 5000
#
# building tree 254 of 5000
# building tree 256 of 5000
# building tree 259 of 5000building tree 257 of 5000
#
# building tree 258 of 5000
# building tree 260 of 5000
# building tree 261 of 5000
# building tree 263 of 5000building tree 262 of 5000
#
# building tree 264 of 5000
# building tree 266 of 5000
# building tree 267 of 5000
# building tree 265 of 5000
# building tree 268 of 5000
# building tree 269 of 5000
# building tree 270 of 5000
# building tree 271 of 5000
# building tree 272 of 5000
# building tree 273 of 5000
# building tree 274 of 5000building tree 275 of 5000
#
# building tree 277 of 5000building tree 276 of 5000
#
# building tree 278 of 5000
# building tree 279 of 5000
# building tree 280 of 5000
# building tree 281 of 5000
# building tree 282 of 5000
# building tree 283 of 5000
# building tree 284 of 5000
# building tree 285 of 5000
# building tree 286 of 5000
# building tree 287 of 5000
# building tree 288 of 5000
# building tree 289 of 5000
# building tree 290 of 5000
# building tree 291 of 5000
# building tree 292 of 5000
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:    2.8s
# building tree 293 of 5000
# building tree 294 of 5000
# building tree 295 of 5000
# building tree 296 of 5000
# building tree 297 of 5000
# building tree 298 of 5000
# building tree 299 of 5000
# building tree 300 of 5000building tree 301 of 5000
#
# building tree 302 of 5000
# building tree 303 of 5000
# building tree 304 of 5000
# building tree 305 of 5000
# building tree 306 of 5000
# building tree 307 of 5000
# building tree 308 of 5000
# building tree 309 of 5000
# building tree 310 of 5000
# building tree 312 of 5000
# building tree 311 of 5000building tree 313 of 5000
#
# building tree 314 of 5000
# building tree 317 of 5000
# building tree 316 of 5000
# building tree 315 of 5000
# building tree 318 of 5000
# building tree 319 of 5000
# building tree 320 of 5000
# building tree 321 of 5000
# building tree 322 of 5000
# building tree 323 of 5000
# building tree 324 of 5000
# building tree 325 of 5000
# building tree 326 of 5000
# building tree 327 of 5000
# building tree 328 of 5000
# building tree 329 of 5000
# building tree 330 of 5000
# building tree 331 of 5000
# building tree 332 of 5000
# building tree 333 of 5000
# building tree 334 of 5000
# building tree 335 of 5000
# building tree 336 of 5000
# building tree 337 of 5000
# building tree 338 of 5000
# building tree 339 of 5000
# building tree 340 of 5000
# building tree 341 of 5000
# building tree 342 of 5000
# building tree 343 of 5000
# building tree 344 of 5000
# building tree 346 of 5000
# building tree 345 of 5000
# building tree 347 of 5000
# building tree 348 of 5000
# building tree 349 of 5000
# building tree 350 of 5000
# building tree 351 of 5000
# building tree 353 of 5000
# building tree 352 of 5000
# building tree 354 of 5000
# building tree 355 of 5000
# building tree 356 of 5000
# building tree 358 of 5000building tree 357 of 5000
#
# building tree 359 of 5000
# building tree 360 of 5000
# building tree 361 of 5000
# building tree 362 of 5000
# building tree 363 of 5000
# building tree 364 of 5000
# building tree 365 of 5000
# building tree 366 of 5000
# building tree 368 of 5000
# building tree 367 of 5000
# building tree 370 of 5000
# building tree 369 of 5000
# building tree 371 of 5000
# building tree 373 of 5000
# building tree 372 of 5000building tree 374 of 5000
#
# building tree 375 of 5000
# building tree 376 of 5000
# building tree 377 of 5000building tree 378 of 5000
#
# building tree 379 of 5000
# building tree 380 of 5000
# building tree 381 of 5000
# building tree 382 of 5000
# building tree 383 of 5000
# building tree 384 of 5000
# building tree 385 of 5000
# building tree 386 of 5000
# building tree 387 of 5000
# building tree 391 of 5000building tree 388 of 5000
#
# building tree 389 of 5000
# building tree 390 of 5000
# building tree 393 of 5000building tree 392 of 5000
#
# building tree 394 of 5000
# building tree 395 of 5000
# building tree 396 of 5000
# building tree 397 of 5000
# building tree 398 of 5000
# building tree 399 of 5000
# building tree 400 of 5000
# building tree 401 of 5000
# building tree 402 of 5000
# building tree 403 of 5000
# building tree 404 of 5000
# building tree 405 of 5000
# building tree 406 of 5000
# building tree 409 of 5000building tree 407 of 5000
#
# building tree 408 of 5000
# building tree 410 of 5000
# building tree 412 of 5000
# building tree 411 of 5000
# building tree 413 of 5000
# building tree 414 of 5000
# building tree 415 of 5000
# building tree 416 of 5000
# building tree 417 of 5000
# building tree 418 of 5000
# building tree 419 of 5000
# building tree 421 of 5000
# building tree 420 of 5000
# building tree 422 of 5000
# building tree 423 of 5000
# building tree 424 of 5000building tree 425 of 5000
#
# building tree 426 of 5000
# building tree 427 of 5000
# building tree 428 of 5000
# building tree 429 of 5000
# building tree 430 of 5000
# building tree 431 of 5000
# building tree 432 of 5000
# building tree 433 of 5000
# building tree 434 of 5000
# building tree 435 of 5000
# building tree 436 of 5000
# building tree 437 of 5000
# building tree 438 of 5000
# building tree 439 of 5000
# building tree 441 of 5000
# building tree 440 of 5000
# building tree 442 of 5000
# building tree 444 of 5000building tree 443 of 5000
#
# building tree 445 of 5000
# building tree 446 of 5000
# building tree 447 of 5000
# building tree 448 of 5000
# building tree 449 of 5000
# building tree 450 of 5000
# building tree 452 of 5000building tree 451 of 5000
#
# building tree 453 of 5000
# building tree 454 of 5000
# building tree 455 of 5000
# building tree 456 of 5000
# building tree 457 of 5000
# building tree 458 of 5000
# building tree 460 of 5000
# building tree 459 of 5000
# building tree 461 of 5000
# building tree 462 of 5000
# building tree 463 of 5000
# building tree 464 of 5000
# building tree 465 of 5000
# building tree 466 of 5000
# building tree 468 of 5000
# building tree 467 of 5000
# building tree 469 of 5000
# building tree 470 of 5000
# building tree 472 of 5000
# building tree 471 of 5000
# building tree 474 of 5000
# building tree 473 of 5000
# building tree 475 of 5000
# building tree 476 of 5000
# building tree 477 of 5000
# building tree 478 of 5000
# building tree 479 of 5000building tree 480 of 5000
#
# building tree 483 of 5000
# building tree 481 of 5000building tree 484 of 5000
#
# building tree 482 of 5000
# building tree 485 of 5000
# building tree 487 of 5000
# building tree 486 of 5000
# building tree 488 of 5000
# building tree 489 of 5000building tree 490 of 5000
#
# building tree 492 of 5000building tree 491 of 5000
#
# building tree 493 of 5000
# building tree 494 of 5000
# building tree 495 of 5000
# building tree 496 of 5000
# building tree 497 of 5000
# building tree 499 of 5000
# building tree 498 of 5000building tree 500 of 5000
#
# building tree 501 of 5000
# building tree 502 of 5000building tree 503 of 5000
#
# building tree 504 of 5000
# building tree 505 of 5000
# building tree 506 of 5000
# building tree 507 of 5000
# building tree 508 of 5000
# building tree 509 of 5000
# building tree 511 of 5000building tree 510 of 5000
#
# building tree 512 of 5000
# building tree 515 of 5000
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:    4.9s
# building tree 514 of 5000building tree 513 of 5000
#
# building tree 516 of 5000
# building tree 517 of 5000
# building tree 518 of 5000
# building tree 519 of 5000
# building tree 520 of 5000
# building tree 521 of 5000
# building tree 522 of 5000
# building tree 523 of 5000
# building tree 524 of 5000
# building tree 525 of 5000
# building tree 526 of 5000
# building tree 527 of 5000
# building tree 528 of 5000building tree 529 of 5000
#
# building tree 530 of 5000
# building tree 531 of 5000
# building tree 532 of 5000
# building tree 533 of 5000
# building tree 534 of 5000
# building tree 535 of 5000
# building tree 536 of 5000
# building tree 537 of 5000
# building tree 538 of 5000
# building tree 539 of 5000
# building tree 540 of 5000
# building tree 541 of 5000
# building tree 542 of 5000
# building tree 543 of 5000
# building tree 544 of 5000
# building tree 545 of 5000
# building tree 546 of 5000
# building tree 547 of 5000
# building tree 548 of 5000
# building tree 549 of 5000
# building tree 550 of 5000
# building tree 551 of 5000
# building tree 552 of 5000
# building tree 553 of 5000building tree 554 of 5000
#
# building tree 555 of 5000
# building tree 556 of 5000
# building tree 558 of 5000
# building tree 557 of 5000
# building tree 559 of 5000
# building tree 560 of 5000
# building tree 561 of 5000
# building tree 562 of 5000
# building tree 563 of 5000building tree 564 of 5000
#
# building tree 565 of 5000
# building tree 566 of 5000
# building tree 567 of 5000
# building tree 568 of 5000
# building tree 569 of 5000
# building tree 570 of 5000
# building tree 571 of 5000
# building tree 572 of 5000
# building tree 574 of 5000
# building tree 573 of 5000
# building tree 575 of 5000
# building tree 576 of 5000
# building tree 578 of 5000building tree 577 of 5000
#
# building tree 579 of 5000building tree 580 of 5000
#
# building tree 581 of 5000building tree 582 of 5000
#
# building tree 583 of 5000
# building tree 586 of 5000
# building tree 584 of 5000building tree 585 of 5000
#
# building tree 587 of 5000
# building tree 588 of 5000building tree 589 of 5000
#
# building tree 590 of 5000
# building tree 592 of 5000
# building tree 594 of 5000building tree 591 of 5000
# building tree 593 of 5000
#
# building tree 597 of 5000
# building tree 595 of 5000
# building tree 596 of 5000
# building tree 598 of 5000
# building tree 599 of 5000
# building tree 600 of 5000
# building tree 601 of 5000
# building tree 602 of 5000
# building tree 604 of 5000
# building tree 603 of 5000
# building tree 605 of 5000
# building tree 607 of 5000building tree 606 of 5000
#
# building tree 608 of 5000
# building tree 609 of 5000
# building tree 611 of 5000building tree 610 of 5000
#
# building tree 612 of 5000
# building tree 613 of 5000
# building tree 614 of 5000
# building tree 615 of 5000
# building tree 616 of 5000
# building tree 617 of 5000
# building tree 618 of 5000
# building tree 619 of 5000
# building tree 620 of 5000
# building tree 622 of 5000
# building tree 623 of 5000building tree 621 of 5000
#
# building tree 624 of 5000
# building tree 626 of 5000
# building tree 627 of 5000
# building tree 625 of 5000
# building tree 628 of 5000
# building tree 629 of 5000
# building tree 630 of 5000
# building tree 631 of 5000
# building tree 632 of 5000
# building tree 633 of 5000
# building tree 634 of 5000
# building tree 635 of 5000
# building tree 636 of 5000
# building tree 637 of 5000
# building tree 638 of 5000
# building tree 640 of 5000
# building tree 639 of 5000building tree 641 of 5000
#
# building tree 642 of 5000
# building tree 644 of 5000
# building tree 643 of 5000
# building tree 645 of 5000
# building tree 646 of 5000
# building tree 647 of 5000
# building tree 648 of 5000
# building tree 649 of 5000
# building tree 650 of 5000
# building tree 651 of 5000
# building tree 652 of 5000
# building tree 653 of 5000
# building tree 654 of 5000
# building tree 655 of 5000
# building tree 656 of 5000
# building tree 657 of 5000
# building tree 658 of 5000
# building tree 659 of 5000
# building tree 660 of 5000
# building tree 661 of 5000
# building tree 662 of 5000
# building tree 663 of 5000building tree 664 of 5000
#
# building tree 665 of 5000
# building tree 666 of 5000
# building tree 667 of 5000
# building tree 669 of 5000building tree 668 of 5000
#
# building tree 670 of 5000
# building tree 671 of 5000
# building tree 672 of 5000
# building tree 673 of 5000
# building tree 674 of 5000
# building tree 675 of 5000
# building tree 677 of 5000building tree 676 of 5000
#
# building tree 678 of 5000
# building tree 679 of 5000
# building tree 681 of 5000
# building tree 680 of 5000
# building tree 682 of 5000
# building tree 683 of 5000
# building tree 684 of 5000
# building tree 685 of 5000
# building tree 686 of 5000
# building tree 687 of 5000building tree 689 of 5000
#
# building tree 688 of 5000
# building tree 690 of 5000
# building tree 692 of 5000
# building tree 691 of 5000building tree 693 of 5000
#
# building tree 694 of 5000
# building tree 695 of 5000
# building tree 696 of 5000
# building tree 697 of 5000
# building tree 698 of 5000
# building tree 699 of 5000
# building tree 700 of 5000
# building tree 701 of 5000
# building tree 702 of 5000
# building tree 703 of 5000
# building tree 704 of 5000
# building tree 705 of 5000
# building tree 707 of 5000building tree 706 of 5000
#
# building tree 708 of 5000
# building tree 709 of 5000
# building tree 710 of 5000
# building tree 711 of 5000
# building tree 712 of 5000
# building tree 714 of 5000
# building tree 713 of 5000
# building tree 715 of 5000
# building tree 716 of 5000
# building tree 717 of 5000
# building tree 718 of 5000
# building tree 719 of 5000
# building tree 720 of 5000
# building tree 721 of 5000
# building tree 722 of 5000
# building tree 723 of 5000
# building tree 724 of 5000
# building tree 725 of 5000
# building tree 726 of 5000building tree 727 of 5000
# building tree 728 of 5000
# building tree 729 of 5000
#
# building tree 733 of 5000
# building tree 730 of 5000building tree 731 of 5000
# building tree 732 of 5000
#
# building tree 734 of 5000building tree 735 of 5000
#
# building tree 737 of 5000building tree 736 of 5000
#
# building tree 738 of 5000
# building tree 739 of 5000
# building tree 740 of 5000building tree 741 of 5000
#
# building tree 742 of 5000
# building tree 743 of 5000
# building tree 744 of 5000
# building tree 745 of 5000
# building tree 748 of 5000
# building tree 747 of 5000
# building tree 749 of 5000
# building tree 746 of 5000
# building tree 750 of 5000
# building tree 751 of 5000
# building tree 752 of 5000building tree 753 of 5000
#
# building tree 754 of 5000
# building tree 757 of 5000
# building tree 755 of 5000
# building tree 756 of 5000
# building tree 758 of 5000
# building tree 759 of 5000
# building tree 760 of 5000
# building tree 761 of 5000
# building tree 762 of 5000
# building tree 765 of 5000building tree 763 of 5000
#
# building tree 764 of 5000
# building tree 766 of 5000building tree 767 of 5000
#
# building tree 768 of 5000
# building tree 769 of 5000
# building tree 770 of 5000
# building tree 772 of 5000
# building tree 771 of 5000
# building tree 773 of 5000
# building tree 774 of 5000
# building tree 775 of 5000
# building tree 776 of 5000
# building tree 777 of 5000
# building tree 778 of 5000
# building tree 780 of 5000
# building tree 779 of 5000
# building tree 781 of 5000
# building tree 782 of 5000
# building tree 783 of 5000
# building tree 784 of 5000
# building tree 785 of 5000
# building tree 786 of 5000
# building tree 787 of 5000
# building tree 788 of 5000
# building tree 790 of 5000
# building tree 789 of 5000
# building tree 791 of 5000
# building tree 792 of 5000
# building tree 793 of 5000
# building tree 794 of 5000
# building tree 795 of 5000
# building tree 796 of 5000
# building tree 797 of 5000building tree 798 of 5000
#
# building tree 799 of 5000
# building tree 800 of 5000
# building tree 802 of 5000
# building tree 801 of 5000
# building tree 803 of 5000
# building tree 804 of 5000
# building tree 805 of 5000
# building tree 806 of 5000
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:    7.7s
# building tree 807 of 5000
# building tree 810 of 5000
# building tree 808 of 5000
# building tree 809 of 5000
# building tree 811 of 5000
# building tree 814 of 5000
# building tree 812 of 5000
# building tree 813 of 5000
# building tree 815 of 5000
# building tree 816 of 5000
# building tree 818 of 5000
# building tree 817 of 5000
# building tree 819 of 5000
# building tree 820 of 5000building tree 822 of 5000
#
# building tree 821 of 5000
# building tree 824 of 5000building tree 823 of 5000
#
# building tree 826 of 5000
# building tree 825 of 5000
# building tree 827 of 5000
# building tree 829 of 5000
# building tree 828 of 5000
# building tree 830 of 5000
# building tree 831 of 5000
# building tree 833 of 5000building tree 832 of 5000
#
# building tree 834 of 5000
# building tree 835 of 5000building tree 836 of 5000
# building tree 837 of 5000
#
# building tree 838 of 5000
# building tree 839 of 5000building tree 840 of 5000
#
# building tree 841 of 5000
# building tree 842 of 5000
# building tree 843 of 5000
# building tree 845 of 5000
# building tree 844 of 5000
# building tree 846 of 5000
# building tree 847 of 5000
# building tree 849 of 5000
# building tree 848 of 5000
# building tree 850 of 5000
# building tree 851 of 5000
# building tree 852 of 5000
# building tree 853 of 5000building tree 854 of 5000
#
# building tree 855 of 5000
# building tree 856 of 5000
# building tree 858 of 5000building tree 857 of 5000
#
# building tree 859 of 5000
# building tree 860 of 5000
# building tree 861 of 5000building tree 862 of 5000
#
# building tree 863 of 5000
# building tree 864 of 5000
# building tree 865 of 5000
# building tree 866 of 5000building tree 867 of 5000
#
# building tree 869 of 5000
# building tree 868 of 5000
# building tree 871 of 5000building tree 870 of 5000
#
# building tree 872 of 5000
# building tree 873 of 5000
# building tree 874 of 5000
# building tree 875 of 5000
# building tree 876 of 5000
# building tree 877 of 5000
# building tree 878 of 5000
# building tree 879 of 5000
# building tree 882 of 5000
# building tree 880 of 5000
# building tree 881 of 5000
# building tree 883 of 5000
# building tree 884 of 5000
# building tree 885 of 5000
# building tree 886 of 5000
# building tree 887 of 5000
# building tree 889 of 5000
# building tree 888 of 5000
# building tree 890 of 5000
# building tree 891 of 5000
# building tree 892 of 5000
# building tree 894 of 5000
# building tree 893 of 5000
# building tree 896 of 5000
# building tree 895 of 5000
# building tree 898 of 5000building tree 897 of 5000
#
# building tree 899 of 5000
# building tree 900 of 5000
# building tree 902 of 5000
# building tree 901 of 5000building tree 903 of 5000
#
# building tree 904 of 5000
# building tree 905 of 5000
# building tree 906 of 5000
# building tree 907 of 5000
# building tree 908 of 5000
# building tree 909 of 5000
# building tree 910 of 5000
# building tree 911 of 5000
# building tree 912 of 5000
# building tree 913 of 5000
# building tree 914 of 5000building tree 915 of 5000
#
# building tree 916 of 5000
# building tree 917 of 5000
# building tree 918 of 5000
# building tree 919 of 5000
# building tree 920 of 5000
# building tree 921 of 5000
# building tree 922 of 5000
# building tree 923 of 5000
# building tree 924 of 5000
# building tree 925 of 5000
# building tree 926 of 5000
# building tree 928 of 5000building tree 927 of 5000
#
# building tree 929 of 5000
# building tree 931 of 5000
# building tree 930 of 5000
# building tree 932 of 5000
# building tree 933 of 5000
# building tree 934 of 5000
# building tree 935 of 5000
# building tree 936 of 5000
# building tree 937 of 5000
# building tree 939 of 5000
# building tree 938 of 5000
# building tree 941 of 5000building tree 940 of 5000
#
# building tree 943 of 5000building tree 942 of 5000
#
# building tree 944 of 5000
# building tree 945 of 5000
# building tree 946 of 5000
# building tree 947 of 5000
# building tree 948 of 5000
# building tree 949 of 5000
# building tree 950 of 5000
# building tree 951 of 5000
# building tree 952 of 5000
# building tree 953 of 5000
# building tree 954 of 5000
# building tree 955 of 5000building tree 956 of 5000
#
# building tree 957 of 5000
# building tree 958 of 5000
# building tree 959 of 5000
# building tree 960 of 5000
# building tree 961 of 5000
# building tree 962 of 5000
# building tree 963 of 5000
# building tree 964 of 5000
# building tree 965 of 5000
# building tree 967 of 5000
# building tree 966 of 5000
# building tree 968 of 5000
# building tree 969 of 5000
# building tree 971 of 5000building tree 970 of 5000
#
# building tree 972 of 5000
# building tree 973 of 5000
# building tree 974 of 5000
# building tree 975 of 5000
# building tree 976 of 5000
# building tree 977 of 5000
# building tree 978 of 5000
# building tree 979 of 5000
# building tree 980 of 5000
# building tree 981 of 5000
# building tree 982 of 5000
# building tree 983 of 5000
# building tree 984 of 5000
# building tree 985 of 5000
# building tree 986 of 5000
# building tree 987 of 5000
# building tree 989 of 5000building tree 988 of 5000
#
# building tree 990 of 5000
# building tree 991 of 5000building tree 992 of 5000
#
# building tree 993 of 5000
# building tree 994 of 5000
# building tree 995 of 5000
# building tree 997 of 5000
# building tree 996 of 5000
# building tree 998 of 5000building tree 999 of 5000
#
# building tree 1000 of 5000
# building tree 1001 of 5000
# building tree 1002 of 5000
# building tree 1003 of 5000
# building tree 1004 of 5000
# building tree 1005 of 5000
# building tree 1006 of 5000
# building tree 1007 of 5000
# building tree 1008 of 5000
# building tree 1009 of 5000
# building tree 1010 of 5000
# building tree 1011 of 5000
# building tree 1013 of 5000
# building tree 1012 of 5000
# building tree 1014 of 5000
# building tree 1015 of 5000
# building tree 1016 of 5000
# building tree 1017 of 5000
# building tree 1019 of 5000building tree 1018 of 5000
#
# building tree 1020 of 5000
# building tree 1021 of 5000
# building tree 1022 of 5000
# building tree 1023 of 5000
# building tree 1024 of 5000building tree 1025 of 5000
#
# building tree 1026 of 5000
# building tree 1027 of 5000
# building tree 1028 of 5000
# building tree 1029 of 5000
# building tree 1030 of 5000
# building tree 1031 of 5000
# building tree 1032 of 5000
# building tree 1033 of 5000
# building tree 1034 of 5000
# building tree 1035 of 5000
# building tree 1036 of 5000
# building tree 1037 of 5000
# building tree 1038 of 5000
# building tree 1039 of 5000
# building tree 1040 of 5000
# building tree 1041 of 5000
# building tree 1042 of 5000
# building tree 1043 of 5000
# building tree 1044 of 5000
# building tree 1045 of 5000
# building tree 1046 of 5000
# building tree 1047 of 5000
# building tree 1048 of 5000
# building tree 1049 of 5000
# building tree 1051 of 5000building tree 1050 of 5000
#
# building tree 1052 of 5000
# building tree 1053 of 5000
# building tree 1054 of 5000
# building tree 1056 of 5000
# building tree 1055 of 5000
# building tree 1057 of 5000
# building tree 1058 of 5000
# building tree 1060 of 5000building tree 1059 of 5000
#
# building tree 1062 of 5000
# building tree 1061 of 5000
# building tree 1063 of 5000
# building tree 1064 of 5000
# building tree 1065 of 5000
# building tree 1066 of 5000
# building tree 1067 of 5000
# building tree 1068 of 5000
# building tree 1069 of 5000
# building tree 1070 of 5000
# building tree 1072 of 5000
# building tree 1071 of 5000
# building tree 1073 of 5000
# building tree 1074 of 5000
# building tree 1075 of 5000
# building tree 1076 of 5000
# building tree 1077 of 5000
# building tree 1078 of 5000
# building tree 1079 of 5000
# building tree 1080 of 5000
# building tree 1081 of 5000
# building tree 1082 of 5000
# building tree 1083 of 5000
# building tree 1084 of 5000
# building tree 1085 of 5000
# building tree 1086 of 5000
# building tree 1087 of 5000building tree 1088 of 5000
#
# building tree 1089 of 5000
# building tree 1090 of 5000
# building tree 1091 of 5000
# building tree 1092 of 5000
# building tree 1093 of 5000
# building tree 1094 of 5000
# building tree 1095 of 5000
# building tree 1096 of 5000
# building tree 1097 of 5000
# building tree 1098 of 5000
# building tree 1099 of 5000
# building tree 1100 of 5000
# building tree 1102 of 5000building tree 1101 of 5000
#
# building tree 1103 of 5000
# building tree 1104 of 5000
# building tree 1105 of 5000
# building tree 1106 of 5000
# building tree 1107 of 5000
# building tree 1109 of 5000
# building tree 1108 of 5000
# building tree 1110 of 5000
# building tree 1111 of 5000
# building tree 1112 of 5000
# building tree 1113 of 5000
# building tree 1114 of 5000
# building tree 1115 of 5000
# building tree 1117 of 5000
# building tree 1116 of 5000building tree 1118 of 5000
#
# building tree 1119 of 5000
# building tree 1120 of 5000
# building tree 1121 of 5000
# building tree 1122 of 5000
# building tree 1123 of 5000
# building tree 1124 of 5000building tree 1125 of 5000
#
# building tree 1126 of 5000
# building tree 1127 of 5000
# building tree 1128 of 5000
# building tree 1129 of 5000
# building tree 1130 of 5000
# building tree 1131 of 5000
# building tree 1132 of 5000
# building tree 1133 of 5000
# building tree 1134 of 5000
# building tree 1135 of 5000
# building tree 1137 of 5000
# building tree 1136 of 5000
# building tree 1138 of 5000
# building tree 1139 of 5000
# building tree 1140 of 5000
# building tree 1141 of 5000
# building tree 1142 of 5000
# building tree 1143 of 5000
# building tree 1144 of 5000
# building tree 1145 of 5000
# building tree 1146 of 5000
# building tree 1148 of 5000building tree 1147 of 5000
#
# building tree 1149 of 5000
# [Parallel(n_jobs=-1)]: Done 1144 tasks      | elapsed:   11.1s
# building tree 1150 of 5000
# building tree 1152 of 5000
# building tree 1151 of 5000
# building tree 1154 of 5000
# building tree 1153 of 5000
# building tree 1155 of 5000
# building tree 1157 of 5000
# building tree 1156 of 5000
# building tree 1158 of 5000
# building tree 1161 of 5000building tree 1160 of 5000building tree 1159 of 5000
#
#
# building tree 1162 of 5000
# building tree 1163 of 5000
# building tree 1165 of 5000
# building tree 1166 of 5000
# building tree 1164 of 5000
# building tree 1167 of 5000
# building tree 1168 of 5000
# building tree 1169 of 5000
# building tree 1170 of 5000
# building tree 1171 of 5000
# building tree 1173 of 5000building tree 1172 of 5000
#
# building tree 1174 of 5000
# building tree 1176 of 5000
# building tree 1175 of 5000
# building tree 1177 of 5000
# building tree 1178 of 5000
# building tree 1181 of 5000building tree 1180 of 5000
# building tree 1179 of 5000
#
# building tree 1183 of 5000
# building tree 1182 of 5000building tree 1184 of 5000
#
# building tree 1185 of 5000
# building tree 1186 of 5000
# building tree 1187 of 5000
# building tree 1188 of 5000
# building tree 1189 of 5000
# building tree 1192 of 5000
# building tree 1190 of 5000
# building tree 1191 of 5000
# building tree 1193 of 5000
# building tree 1195 of 5000
# building tree 1194 of 5000
# building tree 1196 of 5000
# building tree 1197 of 5000
# building tree 1199 of 5000
# building tree 1198 of 5000
# building tree 1200 of 5000building tree 1201 of 5000
#
# building tree 1203 of 5000
# building tree 1202 of 5000
# building tree 1204 of 5000
# building tree 1205 of 5000
# building tree 1207 of 5000building tree 1206 of 5000
#
# building tree 1208 of 5000
# building tree 1209 of 5000
# building tree 1210 of 5000
# building tree 1212 of 5000
# building tree 1211 of 5000
# building tree 1213 of 5000
# building tree 1215 of 5000building tree 1214 of 5000
# building tree 1216 of 5000
#
# building tree 1217 of 5000
# building tree 1220 of 5000
# building tree 1218 of 5000
# building tree 1219 of 5000
# building tree 1221 of 5000building tree 1223 of 5000
#
# building tree 1222 of 5000
# building tree 1224 of 5000
# building tree 1225 of 5000
# building tree 1227 of 5000
# building tree 1226 of 5000
# building tree 1228 of 5000
# building tree 1230 of 5000
# building tree 1229 of 5000
# building tree 1231 of 5000
# building tree 1232 of 5000
# building tree 1233 of 5000
# building tree 1234 of 5000building tree 1235 of 5000
#
# building tree 1236 of 5000
# building tree 1237 of 5000building tree 1238 of 5000
#
# building tree 1239 of 5000
# building tree 1240 of 5000
# building tree 1242 of 5000
# building tree 1241 of 5000
# building tree 1243 of 5000
# building tree 1245 of 5000
# building tree 1246 of 5000
# building tree 1244 of 5000
# building tree 1247 of 5000
# building tree 1249 of 5000
# building tree 1248 of 5000
# building tree 1250 of 5000
# building tree 1251 of 5000
# building tree 1253 of 5000building tree 1252 of 5000
# building tree 1254 of 5000
#
# building tree 1256 of 5000
# building tree 1257 of 5000
# building tree 1255 of 5000
# building tree 1258 of 5000
# building tree 1259 of 5000
# building tree 1261 of 5000
# building tree 1260 of 5000
# building tree 1262 of 5000
# building tree 1263 of 5000
# building tree 1264 of 5000
# building tree 1265 of 5000
# building tree 1266 of 5000
# building tree 1268 of 5000
# building tree 1267 of 5000
# building tree 1269 of 5000
# building tree 1270 of 5000
# building tree 1271 of 5000
# building tree 1272 of 5000building tree 1273 of 5000
#
# building tree 1274 of 5000
# building tree 1275 of 5000
# building tree 1276 of 5000building tree 1277 of 5000
#
# building tree 1279 of 5000building tree 1278 of 5000
#
# building tree 1280 of 5000
# building tree 1281 of 5000
# building tree 1282 of 5000
# building tree 1284 of 5000building tree 1283 of 5000
#
# building tree 1285 of 5000
# building tree 1286 of 5000
# building tree 1287 of 5000
# building tree 1288 of 5000
# building tree 1289 of 5000building tree 1290 of 5000
#
# building tree 1291 of 5000
# building tree 1292 of 5000building tree 1293 of 5000
#
# building tree 1294 of 5000
# building tree 1296 of 5000building tree 1295 of 5000
#
# building tree 1297 of 5000
# building tree 1298 of 5000
# building tree 1300 of 5000
# building tree 1299 of 5000
# building tree 1301 of 5000
# building tree 1302 of 5000
# building tree 1304 of 5000
# building tree 1305 of 5000
# building tree 1303 of 5000
# building tree 1306 of 5000
# building tree 1307 of 5000
# building tree 1309 of 5000
# building tree 1308 of 5000
# building tree 1310 of 5000
# building tree 1311 of 5000
# building tree 1312 of 5000
# building tree 1313 of 5000
# building tree 1314 of 5000
# building tree 1315 of 5000
# building tree 1317 of 5000building tree 1316 of 5000
#
# building tree 1318 of 5000
# building tree 1319 of 5000building tree 1320 of 5000
#
# building tree 1321 of 5000
# building tree 1322 of 5000building tree 1323 of 5000
#
# building tree 1324 of 5000
# building tree 1325 of 5000
# building tree 1326 of 5000
# building tree 1327 of 5000
# building tree 1328 of 5000
# building tree 1329 of 5000
# building tree 1331 of 5000building tree 1330 of 5000
#
# building tree 1333 of 5000
# building tree 1332 of 5000
# building tree 1334 of 5000
# building tree 1335 of 5000
# building tree 1337 of 5000
# building tree 1336 of 5000building tree 1338 of 5000
#
# building tree 1339 of 5000
# building tree 1340 of 5000
# building tree 1341 of 5000
# building tree 1342 of 5000
# building tree 1343 of 5000
# building tree 1344 of 5000
# building tree 1345 of 5000
# building tree 1346 of 5000building tree 1347 of 5000
#
# building tree 1348 of 5000
# building tree 1349 of 5000
# building tree 1350 of 5000
# building tree 1351 of 5000
# building tree 1352 of 5000
# building tree 1353 of 5000
# building tree 1354 of 5000
# building tree 1355 of 5000
# building tree 1356 of 5000
# building tree 1357 of 5000
# building tree 1358 of 5000
# building tree 1359 of 5000
# building tree 1361 of 5000
# building tree 1360 of 5000
# building tree 1362 of 5000
# building tree 1363 of 5000
# building tree 1365 of 5000building tree 1364 of 5000
#
# building tree 1366 of 5000
# building tree 1367 of 5000
# building tree 1369 of 5000
# building tree 1368 of 5000
# building tree 1370 of 5000
# building tree 1371 of 5000
# building tree 1372 of 5000
# building tree 1373 of 5000
# building tree 1374 of 5000
# building tree 1375 of 5000
# building tree 1376 of 5000
# building tree 1377 of 5000
# building tree 1378 of 5000
# building tree 1379 of 5000
# building tree 1380 of 5000
# building tree 1381 of 5000
# building tree 1382 of 5000
# building tree 1383 of 5000
# building tree 1384 of 5000
# building tree 1385 of 5000
# building tree 1386 of 5000
# building tree 1387 of 5000
# building tree 1388 of 5000
# building tree 1389 of 5000
# building tree 1390 of 5000
# building tree 1391 of 5000
# building tree 1392 of 5000
# building tree 1393 of 5000
# building tree 1394 of 5000
# building tree 1395 of 5000building tree 1396 of 5000
#
# building tree 1397 of 5000
# building tree 1398 of 5000
# building tree 1400 of 5000building tree 1399 of 5000
#
# building tree 1401 of 5000
# building tree 1402 of 5000
# building tree 1404 of 5000building tree 1403 of 5000
#
# building tree 1405 of 5000
# building tree 1406 of 5000building tree 1407 of 5000
#
# building tree 1408 of 5000
# building tree 1409 of 5000
# building tree 1412 of 5000building tree 1411 of 5000
#
# building tree 1410 of 5000
# building tree 1414 of 5000
# building tree 1415 of 5000
# building tree 1413 of 5000
# building tree 1416 of 5000
# building tree 1418 of 5000building tree 1417 of 5000
#
# building tree 1419 of 5000
# building tree 1420 of 5000
# building tree 1421 of 5000
# building tree 1422 of 5000
# building tree 1423 of 5000
# building tree 1424 of 5000
# building tree 1425 of 5000
# building tree 1427 of 5000building tree 1426 of 5000
#
# building tree 1428 of 5000
# building tree 1429 of 5000
# building tree 1430 of 5000
# building tree 1431 of 5000
# building tree 1432 of 5000
# building tree 1433 of 5000
# building tree 1434 of 5000
# building tree 1435 of 5000
# building tree 1436 of 5000
# building tree 1437 of 5000
# building tree 1438 of 5000
# building tree 1439 of 5000
# building tree 1440 of 5000
# building tree 1441 of 5000
# building tree 1442 of 5000
# building tree 1443 of 5000
# building tree 1445 of 5000
# building tree 1444 of 5000
# building tree 1446 of 5000
# building tree 1447 of 5000
# building tree 1448 of 5000
# building tree 1449 of 5000
# building tree 1450 of 5000
# building tree 1452 of 5000building tree 1451 of 5000
#
# building tree 1453 of 5000
# building tree 1454 of 5000
# building tree 1456 of 5000building tree 1455 of 5000
#
# building tree 1457 of 5000
# building tree 1458 of 5000
# building tree 1459 of 5000building tree 1460 of 5000
#
# building tree 1461 of 5000
# building tree 1462 of 5000
# building tree 1463 of 5000
# building tree 1464 of 5000
# building tree 1465 of 5000
# building tree 1466 of 5000
# building tree 1467 of 5000
# building tree 1468 of 5000
# building tree 1469 of 5000
# building tree 1470 of 5000
# building tree 1471 of 5000
# building tree 1472 of 5000
# building tree 1473 of 5000
# building tree 1477 of 5000
# building tree 1475 of 5000building tree 1476 of 5000
#
# building tree 1474 of 5000
# building tree 1478 of 5000
# building tree 1479 of 5000
# building tree 1480 of 5000
# building tree 1481 of 5000
# building tree 1482 of 5000building tree 1483 of 5000
#
# building tree 1484 of 5000
# building tree 1485 of 5000
# building tree 1487 of 5000
# building tree 1486 of 5000
# building tree 1488 of 5000
# building tree 1489 of 5000
# building tree 1491 of 5000building tree 1490 of 5000
#
# building tree 1493 of 5000
# building tree 1492 of 5000
# building tree 1494 of 5000
# building tree 1495 of 5000
# building tree 1496 of 5000
# building tree 1497 of 5000
# building tree 1498 of 5000
# building tree 1499 of 5000
# building tree 1501 of 5000
# building tree 1500 of 5000
# building tree 1502 of 5000
# building tree 1503 of 5000
# building tree 1504 of 5000
# building tree 1505 of 5000
# building tree 1506 of 5000building tree 1507 of 5000
#
# building tree 1508 of 5000
# building tree 1509 of 5000
# building tree 1511 of 5000
# building tree 1510 of 5000
# building tree 1512 of 5000
# building tree 1513 of 5000
# building tree 1514 of 5000
# building tree 1515 of 5000
# building tree 1516 of 5000
# building tree 1518 of 5000
# building tree 1517 of 5000building tree 1519 of 5000
#
# building tree 1520 of 5000
# building tree 1523 of 5000
# building tree 1522 of 5000building tree 1521 of 5000
#
# building tree 1524 of 5000
# building tree 1526 of 5000building tree 1525 of 5000
#
# building tree 1527 of 5000
# building tree 1528 of 5000
# building tree 1529 of 5000
# building tree 1532 of 5000
# building tree 1530 of 5000building tree 1531 of 5000
#
# building tree 1533 of 5000
# building tree 1534 of 5000
# building tree 1535 of 5000
# building tree 1536 of 5000
# building tree 1537 of 5000
# building tree 1538 of 5000
# building tree 1539 of 5000
# building tree 1540 of 5000
# building tree 1541 of 5000
# building tree 1542 of 5000
# building tree 1543 of 5000
# building tree 1544 of 5000
# building tree 1545 of 5000building tree 1546 of 5000
#
# building tree 1547 of 5000
# building tree 1548 of 5000
# building tree 1549 of 5000
# building tree 1550 of 5000
# building tree 1551 of 5000building tree 1552 of 5000
#
# building tree 1554 of 5000building tree 1553 of 5000
#
# building tree 1556 of 5000
# building tree 1555 of 5000
# building tree 1557 of 5000
# building tree 1558 of 5000
# building tree 1559 of 5000
# building tree 1560 of 5000building tree 1561 of 5000
#
# building tree 1562 of 5000
# building tree 1563 of 5000
# building tree 1564 of 5000
# building tree 1565 of 5000
# building tree 1566 of 5000
# building tree 1567 of 5000
# building tree 1568 of 5000building tree 1569 of 5000
#
# building tree 1570 of 5000
# building tree 1571 of 5000
# building tree 1573 of 5000building tree 1572 of 5000
#
# building tree 1574 of 5000
# building tree 1576 of 5000
# building tree 1575 of 5000
# building tree 1578 of 5000
# building tree 1577 of 5000
# building tree 1579 of 5000building tree 1580 of 5000
#
# building tree 1582 of 5000building tree 1581 of 5000
# [Parallel(n_jobs=-1)]: Done 1560 tasks      | elapsed:   15.1s
# building tree 1583 of 5000
# building tree 1584 of 5000
# building tree 1585 of 5000
# building tree 1586 of 5000
# building tree 1588 of 5000building tree 1587 of 5000
#
# building tree 1590 of 5000
# building tree 1589 of 5000
# building tree 1591 of 5000
# building tree 1592 of 5000
# building tree 1593 of 5000
# building tree 1594 of 5000
# building tree 1595 of 5000
# building tree 1596 of 5000
# building tree 1597 of 5000
# building tree 1598 of 5000
# building tree 1599 of 5000
# building tree 1600 of 5000
# building tree 1602 of 5000
# building tree 1603 of 5000building tree 1601 of 5000
#
# building tree 1604 of 5000
# building tree 1605 of 5000
# building tree 1606 of 5000building tree 1607 of 5000
#
# building tree 1608 of 5000
# building tree 1609 of 5000
# building tree 1611 of 5000
# building tree 1610 of 5000
# building tree 1612 of 5000
# building tree 1613 of 5000
# building tree 1614 of 5000
# building tree 1615 of 5000
# building tree 1616 of 5000
# building tree 1617 of 5000
# building tree 1618 of 5000
# building tree 1619 of 5000
# building tree 1620 of 5000
# building tree 1621 of 5000
# building tree 1623 of 5000
# building tree 1622 of 5000
# building tree 1624 of 5000
# building tree 1626 of 5000
# building tree 1625 of 5000building tree 1627 of 5000
#
# building tree 1628 of 5000
# building tree 1629 of 5000
# building tree 1630 of 5000
# building tree 1631 of 5000
# building tree 1632 of 5000
# building tree 1633 of 5000
# building tree 1634 of 5000
# building tree 1635 of 5000
# building tree 1636 of 5000
# building tree 1637 of 5000
# building tree 1638 of 5000
# building tree 1639 of 5000
# building tree 1640 of 5000
# building tree 1641 of 5000
# building tree 1642 of 5000
# building tree 1643 of 5000
# building tree 1644 of 5000
# building tree 1645 of 5000
# building tree 1646 of 5000
# building tree 1647 of 5000
# building tree 1648 of 5000
# building tree 1649 of 5000
# building tree 1650 of 5000
# building tree 1651 of 5000
# building tree 1653 of 5000
# building tree 1652 of 5000
# building tree 1654 of 5000
# building tree 1655 of 5000
# building tree 1656 of 5000
# building tree 1657 of 5000
# building tree 1658 of 5000
# building tree 1659 of 5000
# building tree 1660 of 5000
# building tree 1661 of 5000
# building tree 1662 of 5000
# building tree 1663 of 5000
# building tree 1664 of 5000
# building tree 1665 of 5000
# building tree 1666 of 5000
# building tree 1667 of 5000
# building tree 1668 of 5000building tree 1669 of 5000
#
# building tree 1670 of 5000
# building tree 1671 of 5000
# building tree 1672 of 5000
# building tree 1673 of 5000
# building tree 1674 of 5000
# building tree 1675 of 5000
# building tree 1676 of 5000
# building tree 1677 of 5000
# building tree 1678 of 5000
# building tree 1680 of 5000
# building tree 1679 of 5000
# building tree 1681 of 5000
# building tree 1682 of 5000
# building tree 1683 of 5000
# building tree 1684 of 5000
# building tree 1685 of 5000
# building tree 1686 of 5000
# building tree 1687 of 5000
# building tree 1688 of 5000
# building tree 1689 of 5000
# building tree 1690 of 5000
# building tree 1693 of 5000
# building tree 1692 of 5000building tree 1691 of 5000
#
# building tree 1694 of 5000
# building tree 1696 of 5000
# building tree 1695 of 5000building tree 1697 of 5000
#
# building tree 1698 of 5000
# building tree 1699 of 5000building tree 1701 of 5000
#
# building tree 1700 of 5000
# building tree 1704 of 5000building tree 1703 of 5000
# building tree 1702 of 5000
#
# building tree 1705 of 5000
# building tree 1706 of 5000
# building tree 1707 of 5000building tree 1708 of 5000
#
# building tree 1709 of 5000
# building tree 1710 of 5000
# building tree 1711 of 5000
# building tree 1712 of 5000
# building tree 1713 of 5000
# building tree 1714 of 5000
# building tree 1715 of 5000building tree 1716 of 5000
#
# building tree 1717 of 5000
# building tree 1718 of 5000
# building tree 1719 of 5000
# building tree 1720 of 5000
# building tree 1721 of 5000
# building tree 1722 of 5000
# building tree 1723 of 5000building tree 1724 of 5000
#
# building tree 1725 of 5000
# building tree 1726 of 5000
# building tree 1727 of 5000building tree 1729 of 5000
#
# building tree 1728 of 5000
# building tree 1730 of 5000
# building tree 1731 of 5000
# building tree 1732 of 5000building tree 1733 of 5000
#
# building tree 1734 of 5000
# building tree 1735 of 5000
# building tree 1737 of 5000building tree 1736 of 5000
#
# building tree 1739 of 5000
# building tree 1740 of 5000
# building tree 1738 of 5000
# building tree 1741 of 5000
# building tree 1743 of 5000building tree 1742 of 5000
#
# building tree 1744 of 5000
# building tree 1745 of 5000
# building tree 1747 of 5000
# building tree 1746 of 5000
# building tree 1748 of 5000
# building tree 1749 of 5000building tree 1750 of 5000
#
# building tree 1751 of 5000
# building tree 1752 of 5000
# building tree 1753 of 5000
# building tree 1754 of 5000
# building tree 1755 of 5000
# building tree 1756 of 5000
# building tree 1757 of 5000
# building tree 1758 of 5000
# building tree 1759 of 5000
# building tree 1760 of 5000
# building tree 1761 of 5000
# building tree 1762 of 5000building tree 1763 of 5000
#
# building tree 1764 of 5000
# building tree 1765 of 5000
# building tree 1766 of 5000
# building tree 1769 of 5000
# building tree 1768 of 5000
# building tree 1767 of 5000
# building tree 1770 of 5000
# building tree 1771 of 5000
# building tree 1772 of 5000
# building tree 1773 of 5000
# building tree 1774 of 5000
# building tree 1775 of 5000
# building tree 1776 of 5000
# building tree 1777 of 5000
# building tree 1779 of 5000
# building tree 1781 of 5000building tree 1778 of 5000
#
# building tree 1780 of 5000
# building tree 1784 of 5000
# building tree 1783 of 5000
# building tree 1785 of 5000
# building tree 1782 of 5000
# building tree 1786 of 5000
# building tree 1787 of 5000
# building tree 1788 of 5000
# building tree 1789 of 5000
# building tree 1790 of 5000
# building tree 1792 of 5000
# building tree 1791 of 5000
# building tree 1793 of 5000
# building tree 1796 of 5000
# building tree 1794 of 5000
# building tree 1795 of 5000
# building tree 1797 of 5000
# building tree 1798 of 5000
# building tree 1799 of 5000
# ...
# building tree 4419 of 5000
# building tree 4420 of 5000
# building tree 4421 of 5000
# building tree 4422 of 5000
# building tree 4423 of 5000
# building tree 4424 of 5000
# building tree 4425 of 5000
# building tree 4426 of 5000
# building tree 4427 of 5000
# building tree 4430 of 5000building tree 4428 of 5000
# building tree 4429 of 5000
#
# building tree 4431 of 5000
# building tree 4432 of 5000
# building tree 4433 of 5000
# building tree 4434 of 5000
# building tree 4435 of 5000
# building tree 4436 of 5000
# building tree 4437 of 5000
# building tree 4438 of 5000
# building tree 4439 of 5000
# building tree 4440 of 5000
# building tree 4441 of 5000
# building tree 4442 of 5000
# building tree 4443 of 5000
# building tree 4444 of 5000
# building tree 4445 of 5000
# building tree 4446 of 5000
# building tree 4447 of 5000
# building tree 4448 of 5000
# building tree 4449 of 5000
# building tree 4450 of 5000
# building tree 4451 of 5000
# building tree 4452 of 5000
# building tree 4453 of 5000
# building tree 4454 of 5000
# building tree 4456 of 5000
# building tree 4455 of 5000building tree 4457 of 5000
#
# building tree 4458 of 5000
# building tree 4459 of 5000
# building tree 4460 of 5000
# building tree 4461 of 5000
# building tree 4463 of 5000building tree 4462 of 5000
#
# building tree 4464 of 5000
# building tree 4465 of 5000
# building tree 4466 of 5000
# building tree 4467 of 5000
# building tree 4468 of 5000
# building tree 4469 of 5000
# building tree 4470 of 5000
# building tree 4471 of 5000building tree 4472 of 5000
#
# building tree 4473 of 5000
# building tree 4474 of 5000
# building tree 4476 of 5000
# building tree 4475 of 5000
# building tree 4478 of 5000
# building tree 4477 of 5000
# building tree 4479 of 5000
# building tree 4480 of 5000
# building tree 4481 of 5000
# building tree 4482 of 5000
# building tree 4483 of 5000
# building tree 4484 of 5000
# building tree 4485 of 5000building tree 4487 of 5000
#
# building tree 4486 of 5000
# building tree 4490 of 5000
# building tree 4488 of 5000building tree 4489 of 5000
#
# building tree 4491 of 5000
# building tree 4494 of 5000building tree 4493 of 5000
#
# building tree 4492 of 5000
# building tree 4495 of 5000building tree 4496 of 5000
#
# building tree 4497 of 5000building tree 4498 of 5000
#
# building tree 4500 of 5000
# building tree 4501 of 5000building tree 4499 of 5000
#
# building tree 4502 of 5000
# building tree 4505 of 5000building tree 4504 of 5000
#
# building tree 4503 of 5000
# building tree 4506 of 5000
# building tree 4507 of 5000building tree 4508 of 5000
#
# building tree 4509 of 5000
# building tree 4512 of 5000building tree 4513 of 5000
#
# building tree 4510 of 5000
# building tree 4511 of 5000
# building tree 4515 of 5000
# building tree 4514 of 5000
# building tree 4516 of 5000
# building tree 4517 of 5000
# building tree 4518 of 5000
# building tree 4519 of 5000
# building tree 4520 of 5000
# building tree 4521 of 5000
# building tree 4523 of 5000building tree 4522 of 5000
#
# building tree 4524 of 5000
# building tree 4525 of 5000
# building tree 4526 of 5000
# building tree 4527 of 5000
# building tree 4528 of 5000
# building tree 4529 of 5000
# building tree 4530 of 5000building tree 4531 of 5000
#
# building tree 4532 of 5000
# building tree 4533 of 5000
# building tree 4534 of 5000
# building tree 4535 of 5000
# building tree 4536 of 5000
# building tree 4538 of 5000
# building tree 4537 of 5000
# building tree 4539 of 5000
# building tree 4540 of 5000
# building tree 4541 of 5000
# building tree 4542 of 5000
# building tree 4543 of 5000
# building tree 4545 of 5000
# building tree 4544 of 5000
# building tree 4546 of 5000
# building tree 4547 of 5000
# building tree 4548 of 5000
# building tree 4549 of 5000
# building tree 4551 of 5000building tree 4550 of 5000
#
# building tree 4552 of 5000building tree 4553 of 5000
#
# building tree 4554 of 5000
# building tree 4555 of 5000
# building tree 4557 of 5000
# building tree 4556 of 5000
# building tree 4558 of 5000
# building tree 4559 of 5000building tree 4560 of 5000
#
# building tree 4561 of 5000
# building tree 4562 of 5000
# building tree 4563 of 5000building tree 4564 of 5000
#
# building tree 4565 of 5000
# building tree 4566 of 5000
# building tree 4569 of 5000
# building tree 4567 of 5000
# building tree 4568 of 5000
# building tree 4571 of 5000
# building tree 4570 of 5000
# building tree 4572 of 5000
# building tree 4573 of 5000
# building tree 4575 of 5000
# building tree 4574 of 5000
# building tree 4576 of 5000
# building tree 4577 of 5000
# building tree 4579 of 5000
# building tree 4580 of 5000
# building tree 4578 of 5000
# building tree 4581 of 5000
# building tree 4584 of 5000building tree 4582 of 5000
#
# building tree 4583 of 5000
# building tree 4585 of 5000
# building tree 4586 of 5000
# building tree 4587 of 5000
# building tree 4588 of 5000
# building tree 4589 of 5000
# building tree 4590 of 5000building tree 4591 of 5000
#
# building tree 4592 of 5000
# building tree 4593 of 5000
# building tree 4594 of 5000building tree 4596 of 5000building tree 4595 of 5000
#
#
# building tree 4597 of 5000
# building tree 4599 of 5000building tree 4598 of 5000
#
# building tree 4600 of 5000
# building tree 4601 of 5000
# building tree 4603 of 5000
# building tree 4602 of 5000
# building tree 4604 of 5000
# building tree 4605 of 5000
# building tree 4606 of 5000
# building tree 4607 of 5000
# building tree 4608 of 5000building tree 4609 of 5000
#
# building tree 4610 of 5000
# building tree 4611 of 5000
# building tree 4613 of 5000
# [Parallel(n_jobs=-1)]: Done 4600 tasks      | elapsed:   45.5s
# building tree 4614 of 5000
# building tree 4612 of 5000
# building tree 4615 of 5000
# building tree 4616 of 5000
# building tree 4618 of 5000
# building tree 4617 of 5000
# building tree 4619 of 5000
# building tree 4620 of 5000
# building tree 4621 of 5000
# building tree 4622 of 5000building tree 4623 of 5000
#
# building tree 4624 of 5000building tree 4625 of 5000building tree 4626 of 5000
#
#
# building tree 4627 of 5000
# building tree 4628 of 5000
# building tree 4629 of 5000
# building tree 4630 of 5000
# building tree 4631 of 5000
# building tree 4633 of 5000
# building tree 4632 of 5000
# building tree 4634 of 5000
# building tree 4635 of 5000
# building tree 4636 of 5000
# building tree 4637 of 5000
# building tree 4638 of 5000
# building tree 4640 of 5000
# building tree 4639 of 5000
# building tree 4642 of 5000
# building tree 4641 of 5000
# building tree 4643 of 5000
# building tree 4644 of 5000
# building tree 4645 of 5000
# building tree 4646 of 5000
# building tree 4647 of 5000
# building tree 4648 of 5000
# building tree 4649 of 5000
# building tree 4650 of 5000
# building tree 4651 of 5000
# building tree 4652 of 5000
# building tree 4653 of 5000
# building tree 4655 of 5000
# building tree 4654 of 5000
# building tree 4656 of 5000
# building tree 4657 of 5000
# building tree 4659 of 5000building tree 4658 of 5000
#
# building tree 4660 of 5000
# building tree 4662 of 5000
# building tree 4661 of 5000
# building tree 4663 of 5000
# building tree 4665 of 5000
# building tree 4664 of 5000
# building tree 4667 of 5000
# building tree 4666 of 5000
# building tree 4668 of 5000building tree 4669 of 5000
#
# building tree 4670 of 5000
# building tree 4671 of 5000
# building tree 4672 of 5000
# building tree 4673 of 5000
# building tree 4674 of 5000
# building tree 4675 of 5000
# building tree 4676 of 5000
# building tree 4677 of 5000
# building tree 4678 of 5000
# building tree 4679 of 5000
# building tree 4680 of 5000
# building tree 4681 of 5000
# building tree 4682 of 5000
# building tree 4683 of 5000
# building tree 4684 of 5000
# building tree 4685 of 5000
# building tree 4686 of 5000
# building tree 4688 of 5000building tree 4687 of 5000
#
# building tree 4689 of 5000
# building tree 4690 of 5000
# building tree 4692 of 5000
# building tree 4691 of 5000
# building tree 4694 of 5000building tree 4693 of 5000
#
# building tree 4695 of 5000
# building tree 4696 of 5000
# building tree 4698 of 5000building tree 4697 of 5000
#
# building tree 4700 of 5000
# building tree 4699 of 5000
# building tree 4701 of 5000
# building tree 4702 of 5000
# building tree 4703 of 5000
# building tree 4704 of 5000
# building tree 4705 of 5000
# building tree 4708 of 5000
# building tree 4707 of 5000
# building tree 4706 of 5000
# building tree 4709 of 5000
# building tree 4712 of 5000building tree 4710 of 5000
#
# building tree 4711 of 5000
# building tree 4713 of 5000
# building tree 4714 of 5000
# building tree 4715 of 5000
# building tree 4716 of 5000
# building tree 4717 of 5000
# building tree 4718 of 5000
# building tree 4720 of 5000building tree 4719 of 5000
#
# building tree 4721 of 5000
# building tree 4722 of 5000
# building tree 4723 of 5000
# building tree 4724 of 5000
# building tree 4725 of 5000
# building tree 4726 of 5000
# building tree 4727 of 5000
# building tree 4728 of 5000
# building tree 4729 of 5000
# building tree 4730 of 5000
# building tree 4732 of 5000
# building tree 4731 of 5000
# building tree 4733 of 5000
# building tree 4734 of 5000
# building tree 4736 of 5000
# building tree 4735 of 5000
# building tree 4737 of 5000
# building tree 4738 of 5000
# building tree 4739 of 5000
# building tree 4740 of 5000
# building tree 4741 of 5000
# building tree 4742 of 5000
# building tree 4743 of 5000
# building tree 4744 of 5000
# building tree 4745 of 5000
# building tree 4746 of 5000
# building tree 4747 of 5000
# building tree 4748 of 5000
# building tree 4749 of 5000
# building tree 4750 of 5000
# building tree 4751 of 5000
# building tree 4752 of 5000
# building tree 4753 of 5000building tree 4754 of 5000
#
# building tree 4755 of 5000
# building tree 4756 of 5000
# building tree 4757 of 5000building tree 4758 of 5000
#
# building tree 4759 of 5000
# building tree 4763 of 5000building tree 4760 of 5000building tree 4762 of 5000
#
#
# building tree 4761 of 5000
# building tree 4766 of 5000
# building tree 4764 of 5000
# building tree 4765 of 5000
# building tree 4767 of 5000
# building tree 4768 of 5000building tree 4770 of 5000
#
# building tree 4771 of 5000building tree 4769 of 5000
#
# building tree 4772 of 5000
# building tree 4773 of 5000building tree 4774 of 5000
#
# building tree 4775 of 5000
# building tree 4778 of 5000
# building tree 4777 of 5000
# building tree 4776 of 5000
# building tree 4779 of 5000
# building tree 4780 of 5000building tree 4781 of 5000
#
# building tree 4782 of 5000
# building tree 4783 of 5000
# building tree 4784 of 5000
# building tree 4785 of 5000
# building tree 4786 of 5000
# building tree 4787 of 5000
# building tree 4789 of 5000
# building tree 4788 of 5000
# building tree 4790 of 5000
# building tree 4791 of 5000
# building tree 4792 of 5000
# building tree 4793 of 5000
# building tree 4794 of 5000
# building tree 4795 of 5000building tree 4796 of 5000
#
# building tree 4797 of 5000
# building tree 4798 of 5000
# building tree 4799 of 5000building tree 4800 of 5000
#
# building tree 4801 of 5000
# building tree 4802 of 5000
# building tree 4803 of 5000
# building tree 4804 of 5000
# building tree 4805 of 5000
# building tree 4806 of 5000
# building tree 4809 of 5000
# building tree 4807 of 5000
# building tree 4808 of 5000
# building tree 4810 of 5000
# building tree 4812 of 5000
# building tree 4813 of 5000
# building tree 4811 of 5000
# building tree 4814 of 5000
# building tree 4815 of 5000
# building tree 4817 of 5000
# building tree 4816 of 5000
# building tree 4819 of 5000building tree 4818 of 5000
#
# building tree 4820 of 5000
# building tree 4821 of 5000
# building tree 4822 of 5000
# building tree 4823 of 5000
# building tree 4824 of 5000
# building tree 4825 of 5000
# building tree 4826 of 5000
# building tree 4827 of 5000
# building tree 4828 of 5000
# building tree 4829 of 5000
# building tree 4830 of 5000
# building tree 4831 of 5000
# building tree 4832 of 5000
# building tree 4833 of 5000
# building tree 4834 of 5000
# building tree 4835 of 5000
# building tree 4836 of 5000
# building tree 4837 of 5000
# building tree 4838 of 5000
# building tree 4839 of 5000
# building tree 4840 of 5000
# building tree 4841 of 5000
# building tree 4842 of 5000
# building tree 4843 of 5000
# building tree 4844 of 5000
# building tree 4845 of 5000
# building tree 4846 of 5000
# building tree 4847 of 5000
# building tree 4848 of 5000
# building tree 4849 of 5000
# building tree 4850 of 5000
# building tree 4851 of 5000
# building tree 4852 of 5000
# building tree 4853 of 5000building tree 4854 of 5000
#
# building tree 4855 of 5000
# building tree 4856 of 5000
# building tree 4857 of 5000
# building tree 4859 of 5000
# building tree 4858 of 5000
# building tree 4860 of 5000
# building tree 4861 of 5000
# building tree 4862 of 5000
# building tree 4863 of 5000
# building tree 4864 of 5000
# building tree 4866 of 5000building tree 4865 of 5000
#
# building tree 4867 of 5000
# building tree 4869 of 5000building tree 4870 of 5000
# building tree 4868 of 5000
#
# building tree 4871 of 5000
# building tree 4872 of 5000
# building tree 4873 of 5000
# building tree 4874 of 5000
# building tree 4875 of 5000
# building tree 4878 of 5000
# building tree 4877 of 5000building tree 4876 of 5000
#
# building tree 4879 of 5000
# building tree 4882 of 5000
# building tree 4880 of 5000building tree 4881 of 5000
#
# building tree 4884 of 5000
# building tree 4883 of 5000
# building tree 4886 of 5000
# building tree 4885 of 5000
# building tree 4887 of 5000
# building tree 4889 of 5000
# building tree 4888 of 5000
# building tree 4890 of 5000
# building tree 4892 of 5000building tree 4891 of 5000
#
# building tree 4893 of 5000
# building tree 4894 of 5000
# building tree 4896 of 5000
# building tree 4895 of 5000
# building tree 4897 of 5000
# building tree 4898 of 5000
# building tree 4899 of 5000
# building tree 4900 of 5000
# building tree 4901 of 5000
# building tree 4902 of 5000
# building tree 4903 of 5000
# building tree 4904 of 5000
# building tree 4905 of 5000
# building tree 4907 of 5000building tree 4906 of 5000
# building tree 4908 of 5000
#
# building tree 4909 of 5000
# building tree 4912 of 5000building tree 4910 of 5000
#
# building tree 4913 of 5000
# building tree 4911 of 5000
# building tree 4914 of 5000
# building tree 4915 of 5000
# building tree 4916 of 5000
# building tree 4917 of 5000
# building tree 4919 of 5000building tree 4920 of 5000
#
# building tree 4918 of 5000
# building tree 4921 of 5000
# building tree 4923 of 5000building tree 4922 of 5000
# building tree 4924 of 5000
#
# building tree 4925 of 5000
# building tree 4926 of 5000
# building tree 4927 of 5000
# building tree 4928 of 5000
# building tree 4929 of 5000
# building tree 4930 of 5000
# building tree 4931 of 5000
# building tree 4932 of 5000
# building tree 4933 of 5000
# building tree 4934 of 5000
# building tree 4936 of 5000building tree 4935 of 5000
#
# building tree 4937 of 5000
# building tree 4938 of 5000building tree 4940 of 5000
#
# building tree 4939 of 5000
# building tree 4941 of 5000
# building tree 4943 of 5000building tree 4942 of 5000
#
# building tree 4944 of 5000
# building tree 4945 of 5000
# building tree 4946 of 5000
# building tree 4947 of 5000
# building tree 4949 of 5000building tree 4948 of 5000
#
# building tree 4950 of 5000
# building tree 4951 of 5000
# building tree 4953 of 5000building tree 4952 of 5000
#
# building tree 4954 of 5000
# building tree 4955 of 5000
# building tree 4956 of 5000
# building tree 4957 of 5000
# building tree 4958 of 5000
# building tree 4959 of 5000
# building tree 4960 of 5000
# building tree 4961 of 5000
# building tree 4962 of 5000
# building tree 4964 of 5000
# building tree 4963 of 5000
# building tree 4965 of 5000
# building tree 4966 of 5000building tree 4968 of 5000
#
# building tree 4967 of 5000
# building tree 4969 of 5000
# building tree 4971 of 5000
# building tree 4970 of 5000
# building tree 4972 of 5000
# building tree 4973 of 5000
# building tree 4974 of 5000
# building tree 4975 of 5000
# building tree 4976 of 5000
# building tree 4977 of 5000
# building tree 4979 of 5000
# building tree 4978 of 5000
# building tree 4980 of 5000
# building tree 4981 of 5000
# building tree 4982 of 5000
# building tree 4983 of 5000
# building tree 4984 of 5000
# building tree 4985 of 5000
# building tree 4986 of 5000
# building tree 4987 of 5000
# building tree 4988 of 5000
# building tree 4989 of 5000
# building tree 4990 of 5000
# building tree 4991 of 5000building tree 4992 of 5000
#
# building tree 4993 of 5000
# building tree 4994 of 5000
# building tree 4995 of 5000
# building tree 4996 of 5000
# building tree 4999 of 5000
# building tree 4997 of 5000building tree 4998 of 5000
#
# building tree 5000 of 5000
# [Parallel(n_jobs=-1)]: Done 5000 out of 5000 | elapsed:   49.5s finished
# BalancedRandomForestClassifier(class_weight='balanced_subsample',
#                                n_estimators=5000, n_jobs=-1, verbose=3)

# %%
y_pred_modelo1_rev2 = rf_2.predict(newX_train_modelo1_rev2_df)
print(y_pred_modelo1_rev2)
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 120 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done 504 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 1144 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 1560 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 2040 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done 2584 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done 3192 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=4)]: Done 3864 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=4)]: Done 4600 tasks      | elapsed:    3.8s
# [0 1 0 ... 1 0 0]
# [Parallel(n_jobs=4)]: Done 5000 out of 5000 | elapsed:    4.2s finished

# %%
y_pred_prob_modelo1_rev2 = rf_2.predict_proba(newX_train_modelo1_rev2_df)
print(y_pred_prob_modelo1_rev2)
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 120 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 504 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 1144 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 1560 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 2040 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 2584 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done 3192 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 3864 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 4600 tasks      | elapsed:    3.2s
# [[0.8978 0.1022]
#  [0.133  0.867 ]
#  [0.8098 0.1902]
#  ...
#  [0.3366 0.6634]
#  [0.8456 0.1544]
#  [0.8254 0.1746]]
# [Parallel(n_jobs=4)]: Done 5000 out of 5000 | elapsed:    3.5s finished

# %% [markdown]
# ## 2.2 Prestaciones

# %% [markdown]
# La **sensibilidad y la especificidad** son dos valores que nos indican la capacidad de nuestro estimador para discriminar los casos positivos, de los negativos. La sensibilidad es la fracción de verdaderos positivos, mientras que la especificidad, es la fracción de verdaderos negativos.
#
# -  **La sensibilidad** es la proporción de casos positivos que fueron correctamente identificadas por el algoritmo.
# -  **La especificidad** se trata de los casos negativos que el algoritmo ha clasificado correctamente.  Expresa cuan bien puede el modelo detectar esa clase.
# - **La Precisión** se refiere a la dispersión del conjunto de valores obtenidos a partir de mediciones repetidas de una magnitud. Cuanto menor es la dispersión mayor la precisión. Se representa por la proporción entre el número de predicciones correctas (tanto positivas como negativas) y el total de predicciones. En forma práctica es  el porcentaje de casos positivos detectados.

# %% [markdown]
# ### Prestaciones en train

# %%
from sklearn.metrics import confusion_matrix, plot_confusion_matrix

# %%
#cm = confusion_matrix(y_train_adasyn,y_pred)
cm = confusion_matrix(y_train,y_pred_modelo1_rev2)

#plot_confusion_matrix(rf_1,X_train_adasyn,y_train_adasyn,cmap=plt.cm.Blues)
plot_confusion_matrix(rf_2,newX_train_modelo1_rev2_df,y_train,cmap=plt.cm.Blues)

plt.show()

accuracy1=(cm[0,0]+cm[1,1])/(cm[1,0]+cm[1,1]+cm[0,0]+cm[0,1])
print ('Accuracy : ', accuracy1)

sensitivity1 = cm[1,1]/(cm[1,0]+cm[1,1])
print('Sensitivity : ', sensitivity1 )

specificity1 = cm[0,0]/(cm[0,0]+cm[0,1])  #ojo, creo que está al revés esto
print('Specificity : ', specificity1)

from imblearn.metrics import classification_report_imbalanced

print(classification_report_imbalanced(y_train, y_pred_modelo1_rev2))
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 120 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 504 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done 1144 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 1560 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 2040 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 2584 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done 3192 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 3864 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=4)]: Done 4600 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=4)]: Done 5000 out of 5000 | elapsed:    3.3s finished
# Accuracy :  0.7015945330296127
# Sensitivity :  1.0
# Specificity :  0.6757425742574258
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       1.00      0.68      1.00      0.81      0.82      0.65      1212
#           1       0.21      1.00      0.68      0.35      0.82      0.70       105
#
# avg / total       0.94      0.70      0.97      0.77      0.82      0.66      1317

# %% [markdown]
# ### Prestaciones en test

# %%
#modify NaNs in X_test

feature_names = ['Age','Weight','Size','IMC','Creatinine','Cystatin','HDL','LDL','Triglyciredes','GOT','GPT','GGT','Albuminuria','Ferritin','HOMA','Insulin','Blood_Glucose','Glycated-HB','PCR','Vitamin-D','TAS','TAD','Date']

X_test_modelo1_rev2 = pd.DataFrame(X_test[:,1,:],columns = feature_names[:-1])

X_test_modelo1_rev2 = X_test_modelo1_rev2.drop('Blood_Glucose',axis = 1)
X_test_modelo1_rev2 = X_test_modelo1_rev2.drop('Glycated-HB',axis = 1)

#impute

X_test_modelo1_rev2 = X_test_modelo1_rev2.fillna(X_train_sin_NaN_modelo1_rev2.median())
#newX_test = np.concatenate((X_test_2, Prob_test[:,None]), axis=1)

newX_test_modelo1_rev2 = np.concatenate((X_test_modelo1_rev2, Prob_test_without_BG_HB[:,np.newaxis]), axis=1)
#newX_test_modelo1_rev2_df = pd.DataFrame(newX_test_modelo1_rev22)

y_pred_test_modelo1_rev2 = rf_2.predict(newX_test_modelo1_rev2)
y_pred_test_prob_modelo1_rev2 = rf_2.predict_proba(newX_test_modelo1_rev2)


plot_confusion_matrix(rf_2,newX_test_modelo1_rev2,y_test,cmap=plt.cm.Blues)

plt.show()
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 120 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 504 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done 1144 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done 1560 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2040 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 2584 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 3192 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done 3864 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 4600 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 5000 out of 5000 | elapsed:    3.1s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 120 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 504 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done 1144 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 1560 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 2040 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 2584 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done 3192 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 3864 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=4)]: Done 4600 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=4)]: Done 5000 out of 5000 | elapsed:    3.2s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 120 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 504 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done 1144 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 1560 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2040 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 2584 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 3192 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done 3864 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 4600 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=4)]: Done 5000 out of 5000 | elapsed:    2.9s finished

# %%
cm1 = confusion_matrix(y_test,y_pred_test_modelo1_rev2)

accuracy1=(cm1[0,0]+cm1[1,1])/(cm1[0,0]+cm1[0,1]+cm1[1,0]+cm1[1,1])
print ('Accuracy : ', accuracy1)

specificity1 = cm1[0,0]/(cm1[0,0]+cm1[0,1])
print('Specificity : ', specificity1 )

sensitivity1 = cm1[1,1]/(cm1[1,0]+cm1[1,1])
print('Sensitivity : ', sensitivity1)
# Out:
# Accuracy :  0.5757575757575758
# Specificity :  0.5610561056105611
# Sensitivity :  0.7407407407407407

# %% [markdown]
# # Aplicamos el modelo eliminando las variables Vitamin-D, HOMA e Insulin

# %% [markdown]
# # 1. PREPROCESADO

# %%
def data_nan_review_analysis_1(X):
    """
    Function that takes as input a matrix with pats and features for one review, and gets back
    X_train_rev_imputed,pats_to_drop,feature_to_drop,imputation_data
    """
    feature_names = ['Age','Weight','Size','IMC','Creatinine','Cystatin','HDL','LDL','Triglyciredes','GOT','GPT','GGT','Albuminuria','Ferritin','HOMA','Insulin','Blood_Glucose','Glycated-HB','PCR','Vitamin-D','TAS','TAD','Date']
    
    df = pd.DataFrame(X,columns = feature_names[:-1]) #convert it to df #delete date [:-1]
    
    print(df.columns)
    df = df.drop('HOMA',axis = 1)
    df = df.drop('Insulin',axis = 1)
    df = df.drop('Blood_Glucose',axis = 1)
    df = df.drop('Glycated-HB',axis = 1)
    df = df.drop('Vitamin-D',axis = 1)
    
    
    
    #initialize vars to return
    X_train_rev_imputed = []
    pats_to_drop = []
    feature_to_drop = []
    imputation_data = []
    #check number of NaNs per feature
    
    for index,value in enumerate (df.isnull().sum()):
        if value !=0:
            print(df.columns[index],value)
            
    #Drop features: Blood_Glucose and Glycated_HB
    

    ##reemplazar cada valor por la mediana 
    
    X_train_rev_imputed = df.fillna(df.median()) 
    
    return X_train_rev_imputed,pats_to_drop,feature_to_drop,imputation_data

def imputing_data_1(X):
    """ 
    Function that check data with nans and replace them with appropriate imputation
    """
    X_train_aux = X_train.copy()
    num_review = X_train_aux.shape[1]
    
    X_train_imp = []
    
    #run over the reviews and get the X_train_imputed, pats_to_drop, feature_to_drop, and imputation values
    for i in range(3):
        print("review",i)
        print("----------")
        X_train_rev_imputed,pats_to_drop,feature_to_drop,imputation_data = data_nan_review_analysis_1(X_train_aux[:,i,:])
        print("----------")
        print("----------")
        
        X_train_imp.append(X_train_rev_imputed)
        
    return X_train_imp

# %%
X_train_sin_NaN_modelo2_rev2_imputing = imputing_data_1(X_train)
# Out:
# review 0
# ----------
# Index(['Age', 'Weight', 'Size', 'IMC', 'Creatinine', 'Cystatin', 'HDL', 'LDL',
#        'Triglyciredes', 'GOT', 'GPT', 'GGT', 'Albuminuria', 'Ferritin', 'HOMA',
#        'Insulin', 'Blood_Glucose', 'Glycated-HB', 'PCR', 'Vitamin-D', 'TAS',
#        'TAD'],
#       dtype='object')
# Weight 15
# Size 6
# IMC 19
# Creatinine 21
# Cystatin 263
# HDL 115
# LDL 135
# Triglyciredes 24
# GOT 198
# GPT 26
# GGT 54
# Albuminuria 209
# Ferritin 133
# PCR 231
# ----------
# ----------
# review 1
# ----------
# Index(['Age', 'Weight', 'Size', 'IMC', 'Creatinine', 'Cystatin', 'HDL', 'LDL',
#        'Triglyciredes', 'GOT', 'GPT', 'GGT', 'Albuminuria', 'Ferritin', 'HOMA',
#        'Insulin', 'Blood_Glucose', 'Glycated-HB', 'PCR', 'Vitamin-D', 'TAS',
#        'TAD'],
#       dtype='object')
# Age 2
# Weight 13
# Size 4
# IMC 15
# Creatinine 5
# Cystatin 141
# HDL 100
# LDL 119
# Triglyciredes 8
# GOT 200
# GPT 8
# GGT 35
# Albuminuria 166
# Ferritin 81
# PCR 132
# ----------
# ----------
# review 2
# ----------
# Index(['Age', 'Weight', 'Size', 'IMC', 'Creatinine', 'Cystatin', 'HDL', 'LDL',
#        'Triglyciredes', 'GOT', 'GPT', 'GGT', 'Albuminuria', 'Ferritin', 'HOMA',
#        'Insulin', 'Blood_Glucose', 'Glycated-HB', 'PCR', 'Vitamin-D', 'TAS',
#        'TAD'],
#       dtype='object')
# Age 112
# Weight 121
# Size 112
# IMC 123
# Creatinine 119
# Cystatin 250
# HDL 206
# LDL 227
# Triglyciredes 126
# GOT 338
# GPT 124
# GGT 147
# Albuminuria 276
# Ferritin 186
# PCR 252
# TAS 109
# TAD 109
# ----------
# ----------

# %%
#Get the second review

X_train_sin_NaN_modelo2_rev2 = X_train_sin_NaN_modelo2_rev2_imputing[1]

# %%
newX_train_modelo2_rev2 = np.concatenate((X_train_sin_NaN_modelo2_rev2, Prob_train_1_without_BG_HB_VD_Ins_HOMA[:,np.newaxis]), axis=1)

# %%
newX_train_modelo2_rev2_df = pd.DataFrame(newX_train_modelo2_rev2)

# %% [markdown]
# # 2. PREDICCIÓN

# %% [markdown]
# ## 2.1 Random Forest

# %%
from sklearn.model_selection import RandomizedSearchCV
# Number of features to consider at every split
max_features = ['auto', 'sqrt','log2']
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4,8,10,12,14,16,18,20]
# Create the random grid
random_grid = {'max_features': max_features,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,}
print(random_grid)
# Out:
# {'max_features': ['auto', 'sqrt', 'log2'], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4, 8, 10, 12, 14, 16, 18, 20]}

# %%
# First create the base model to tune
rf_11 = BalancedRandomForestClassifier(n_estimators=50, criterion='gini',  
                   bootstrap=True, oob_score=False, class_weight = 'balanced_subsample')

# %%
from sklearn.model_selection import GridSearchCV
# Use the random grid to search for best hyperparameters
# Grid search of parameters, using 7 fold cross validation,

grid_random = GridSearchCV(rf_11, random_grid, cv=7 , n_jobs = -1, verbose = 5)

# %%
# Fit the random search model
grid_random.fit(newX_train_modelo2_rev2_df, y_train)
# Out:
# Fitting 7 folds for each of 90 candidates, totalling 630 fits
# GridSearchCV(cv=7,
#              estimator=BalancedRandomForestClassifier(class_weight='balanced_subsample',
#                                                       n_estimators=50),
#              n_jobs=-1,
#              param_grid={'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4, 8, 10, 12, 14, 16, 18,
#                                               20],
#                          'min_samples_split': [2, 5, 10]},
#              verbose=5)

# %%
grid_random.best_params_
# Out:
# {'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}

# %% [markdown]
# ### Rebalancea dentro de cada árbol

# %%
rf_22 = BalancedRandomForestClassifier(n_estimators=5000, criterion='gini', max_features = grid_random.best_params_['max_features'],
                min_samples_leaf = grid_random.best_params_['min_samples_leaf'], min_samples_split = grid_random.best_params_['min_samples_split'],    
                   bootstrap=True, oob_score=False, class_weight = 'balanced_subsample')

# %%
rf_22.fit(newX_train_modelo2_rev2_df, y_train)
# Out:
# BalancedRandomForestClassifier(class_weight='balanced_subsample',
#                                max_features='sqrt', n_estimators=5000)

# %%
y_pred_modelo2_rev2 = rf_22.predict(newX_train_modelo2_rev2_df)
y_pred_1_prob_modelo2_rev2 = rf_22.predict_proba(newX_train_modelo2_rev2_df)

# %% [markdown]
# ## 2.2 Calibración de la probabilidad

# %%
'''from sklearn.calibration import CalibratedClassifierCV

base_clf = BalancedRandomForestClassifier(n_estimators=50, criterion='gini', max_features = grid_random.best_params_['max_features'],
                min_samples_leaf = grid_random.best_params_['min_samples_leaf'], min_samples_split = grid_random.best_params_['min_samples_split'],    
                   bootstrap=True, oob_score=False, class_weight = 'balanced_subsample')

#vamos a calibrar training
calibrated_clf = CalibratedClassifierCV(base_estimator=rf_22,cv='prefit', method = 'sigmoid',ensemble = False)

calibrated_clf.fit(X_train_11, y_train)'''

# %%
'''#calibrated_clf.
from sklearn.calibration import calibration_curve

feature_names = ['Age','Weight','Size','IMC','Creatinine','Cystatin','HDL','LDL','Triglyciredes','GOT','GPT','GGT','Albuminuria','Ferritin','HOMA','Insulin','Blood_Glucose','Glycated-HB','PCR','Vitamin-D','TAS','TAD','Date']

X_test_1 = pd.DataFrame(X_test[:,0,:],columns = feature_names[:-1])

X_test_1 = X_test_1.drop('Blood_Glucose',axis = 1)
X_test_1 = X_test_1.drop('Glycated-HB',axis = 1)
X_test_1 = X_test_1.drop('HOMA',axis = 1)
X_test_1 = X_test_1.drop('Insulin',axis = 1)
X_test_1 = X_test_1.drop('Vitamin-D',axis = 1)

X_test_1 = X_test_1.fillna(X_train_1.median())


y_pred_cali = calibrated_clf.predict_proba(X_test_1)[:,1]

y_train_cali = calibrated_clf.predict_proba(X_train_11)[:,1]

fraction_of_positives, mean_predicted_value = calibration_curve(y_test, y_pred_cali, n_bins=10)
fraction_of_positives_train, mean_predicted_value_train = calibration_curve(y_train, y_train_cali, n_bins=10)

plt.figure()
plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
plt.plot(mean_predicted_value, fraction_of_positives, "s-")
plt.plot(mean_predicted_value_train, fraction_of_positives_train, "^-")


plt.figure()
plt.hist(y_pred_cali, range=(0, 1), bins=10,histtype="step", lw=2)
plt.hist(y_train_cali, range=(0, 1), bins=10,histtype="step", lw=2)


plt.hist(rf_22.predict_proba(X_train_11)[:,1],bins = 10,histtype='step')'''

# %% [markdown]
# ## 2.3 Prestaciones

# %% [markdown]
# ### Prestaciones en train

# %%
from sklearn.metrics import confusion_matrix, plot_confusion_matrix

# %%
cm = confusion_matrix(y_train,y_pred_modelo2_rev2)
print(cm)

#plot_confusion_matrix(rf_1,X_train_adasyn,y_train_adasyn,cmap=plt.cm.Blues)
plot_confusion_matrix(rf_22,newX_train_modelo2_rev2_df,y_train,cmap=plt.cm.Blues)

plt.show()

accuracy1=(cm[0,0]+cm[1,1])/(cm[1,0]+cm[1,1]+cm[0,0]+cm[0,1])
print ('Accuracy : ', accuracy1)

sensitivity1 = cm[1,1]/(cm[1,0]+cm[1,1])
print('Sensitivity : ', sensitivity1 )

specificity1 = cm[0,0]/(cm[0,0]+cm[0,1])
print('Specificity : ', specificity1)


from sklearn.metrics import roc_curve, auc
from sklearn.metrics import plot_roc_curve

plot_roc_curve(rf_22, newX_train_modelo2_rev2_df, y_train)
plt.show()
# Out:
# [[791 421]
#  [  0 105]]
# Accuracy :  0.680334092634776
# Sensitivity :  1.0
# Specificity :  0.6526402640264026

# %% [markdown]
# ### Prestaciones en test

# %%
#modify NaNs in X_test

feature_names = ['Age','Weight','Size','IMC','Creatinine','Cystatin','HDL','LDL','Triglyciredes','GOT','GPT','GGT','Albuminuria','Ferritin','HOMA','Insulin','Blood_Glucose','Glycated-HB','PCR','Vitamin-D','TAS','TAD','Date']

X_test_modelo2_rev2 = pd.DataFrame(X_test[:,1,:],columns = feature_names[:-1])

X_test_modelo2_rev2 = X_test_modelo2_rev2.drop('Blood_Glucose',axis = 1)
X_test_modelo2_rev2 = X_test_modelo2_rev2.drop('Glycated-HB',axis = 1)
X_test_modelo2_rev2 = X_test_modelo2_rev2.drop('HOMA',axis = 1)
X_test_modelo2_rev2 = X_test_modelo2_rev2.drop('Insulin',axis = 1)
X_test_modelo2_rev2 = X_test_modelo2_rev2.drop('Vitamin-D',axis = 1)

#impute

X_test_modelo2_rev2 = X_test_modelo2_rev2.fillna(X_train_sin_NaN_modelo2_rev2.median())
newX_test_modelo2_rev2 = np.concatenate((X_test_modelo2_rev2, Prob_test_1_without_BG_HB_VD_Ins_HOMA[:,np.newaxis]), axis=1)

y_pred_test_modelo2_rev2 = rf_22.predict(newX_test_modelo2_rev2)
y_pred_test_proba_modelo2_rev2 = rf_22.predict_proba(newX_test_modelo2_rev2) #Probabilidad de pertenecer a cada clase

plot_confusion_matrix(rf_22,newX_test_modelo2_rev2,y_test,cmap=plt.cm.Blues)

plt.show()

# %%
cm1 = confusion_matrix(y_test,y_pred_test_modelo2_rev2)
print(cm1)

accuracy1=(cm1[0,0]+cm1[1,1])/(cm[1,0]+cm[1,1]+cm[0,0]+cm[0,1])
print ('Accuracy : ', accuracy1)

sensitivity1 = cm1[1,1]/(cm1[1,0]+cm1[1,1])
print('Sensitivity : ', sensitivity1 )

specificity1 = cm1[0,0]/(cm1[0,0]+cm1[0,1])
print('Specificity : ', specificity1)


from sklearn.metrics import roc_curve, auc
from sklearn.metrics import plot_roc_curve

plot_roc_curve(rf_22, newX_test_modelo2_rev2, y_test)
plt.show()
# Out:
# [[167 136]
#  [  7  20]]
# Accuracy :  0.1419893697798026
# Sensitivity :  0.7407407407407407
# Specificity :  0.5511551155115512
